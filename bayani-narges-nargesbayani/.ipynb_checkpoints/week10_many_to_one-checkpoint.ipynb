# %% [markdown]
# # Getting things going and highlighting "the problem"

# %%
import pandas as pd
import sqlite3

ramphs = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/roman-amphitheaters.csv")
chronogrps = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/chronogrps.csv")

# I put an uncompressed version of pleiades-places into my folder on the github repo
pleiades = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/heath-sebastian/pleiades-places.csv")

# One note: because it takes a long time to load the pleiades data,
# avoid running this cell again unless necessary
# As I look back on class, perhaps this is why Mikael reported 
# that his replace was taking a long time. Was the data reloading across the internet?

# %%
# ramphs, chronogrps, and pleiades are now pandas DataFrames

print(type(ramphs))
print(type(chronogrps))
print(type(pleiades))

# Again, these are pandas DataFrames, not sql tables!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# OK, to our problem in class.

# inspect the values in both DataFrmes
print(ramphs['pleiades'].head(2))
print(pleiades['id'].head(2))

# They're different. Bummer.
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object
# 0    265876
# 1    265877
# Name: id, dtype: int64

# %% [markdown]
# # A tiny bit of string manipulation

# %%
tmp = "Hello World"
tmp.replace("Hello", "") # note that this doesn't remove the space
# Out:
# ' World'

# %% [markdown]
# # A little bit of pandas dataframe manipulation

# %%
# first
ramphs.head(2)
# Out:
#                         id                         title  label  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos   Dura
# 1        arlesAmphitheater         Amphitheater at Arles  Arles
#
#                                  pleiades          type  capacity modcountry  \
# 0  http://pleiades.stoa.org/places/893989  amphitheater      1000      Syria
# 1  http://pleiades.stoa.org/places/148217  amphitheater     20000     France
#
#   chronogrp certainty                                      youtube  extmajor  \
# 0   Severan       NaN                                          NaN        50
# 1   Flavian       NaN  https://www.youtube.com/watch?v=oCz-76hb1LU       136
#
#    extminor  arenamajor  arenaminor   latitude  longitude  elevation
# 0        44          31          25  34.749855  40.728926        223
# 1       107          47          32  43.677778   4.631111         21

# %%
# then
ramphs['pleiades'].head(2)

# so it's easy to output either all columns, or just a selection.
# And it's likely that your notebook is trying to nicely format the output of ramphs.head(2).
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object

# %%
# it's easy to create new columns
ramphs['new'] = "test"
ramphs['new'].head(5)

# And look!!!! Very important to note that pandas will automatically assign "test" to all rows.
# That's one of its great powers.
# Out:
# 0    test
# 1    test
# 2    test
# 3    test
# 4    test
# Name: new, dtype: object

# %%
# combining pandas and string manipulation
ramphs['new'].str.replace("e","").head(5) # do note the ".str" before ".replace"

# Again, pandas calculates result for all rows
# Out:
# 0    tst
# 1    tst
# 2    tst
# 3    tst
# 4    tst
# Name: new, dtype: object

# %%
# here's a useful construct, though dangerous in that 
# it changes data (a concern some of you raised in class)


ramphs['new'] = ramphs['new'].str.replace("t","")
ramphs['new'].head(5)
# Out:
# 0    es
# 1    es
# 2    es
# 3    es
# 4    es
# Name: new, dtype: object

# %% [markdown]
# # Review of adding tables to an sql database (to keep our terminology straight)

# %%
# The conn variable is a 'database connection'
# we are making this database in memory, meaning it won't be saved
conn = sqlite3.connect(':memory:')

# as convenience, I've put the above in a separate cell. You may not need to run it again.

# %%
# the following two lines create sql tables from pandas DataFrames
ramphs.to_sql('ramphs',conn, if_exists="replace")
chronogrps.to_sql('chronogrps', conn,if_exists="replace")

pleiades.to_sql('pleiades', conn, if_exists="replace")


# copy-paste, then edit one of the the above lines to make a pleiades table

# %%
# let's test that we have sql tables
pd.read_sql("""SELECT id,pleiades FROM RAMPHS WHERE capacity > 40000""",conn)
 
# but that only confirms all is well working for the ramphs table.
# Good to test others as well.
# Out:
#                         id                                pleiades
# 0  romeFlavianAmphitheater  http://pleiades.stoa.org/places/423025

# %%
# a reminder
pd.read_sql("""PRAGMA table_info(pleiades)""",conn)
# will display the columns in the pleiades table (assuming you called it 'pleiades')
# look at those columns, which ones have 'chronological' information
# Out:
#     cid                name     type  notnull dflt_value  pk
# 0     0               index  INTEGER        0       None   0
# 1     1             authors     TEXT        0       None   0
# 2     2                bbox     TEXT        0       None   0
# 3     3        connectsWith     TEXT        0       None   0
# 4     4             created     TEXT        0       None   0
# 5     5            creators     TEXT        0       None   0
# 6     6      currentVersion  INTEGER        0       None   0
# 7     7         description     TEXT        0       None   0
# 8     8              extent     TEXT        0       None   0
# 9     9        featureTypes     TEXT        0       None   0
# 10   10          geoContext     TEXT        0       None   0
# 11   11  hasConnectionsWith     TEXT        0       None   0
# 12   12                  id  INTEGER        0       None   0
# 13   13   locationPrecision     TEXT        0       None   0
# 14   14             maxDate     REAL        0       None   0
# 15   15             minDate     REAL        0       None   0
# 16   16            modified     TEXT        0       None   0
# 17   17                path     TEXT        0       None   0
# 18   18             reprLat     REAL        0       None   0
# 19   19         reprLatLong     TEXT        0       None   0
# 20   20            reprLong     REAL        0       None   0
# 21   21                tags     TEXT        0       None   0
# 22   22         timePeriods     TEXT        0       None   0
# 23   23     timePeriodsKeys     TEXT        0       None   0
# 24   24    timePeriodsRange     TEXT        0       None   0
# 25   25               title     TEXT        0       None   0
# 26   26                 uid     TEXT        0       None   0

# %% [markdown]
# # More mixing of pandas and sql

# %%
# worth noting that the result of pd.read_sql statement is a pandas DataFrame
type(pd.read_sql("""SELECT id FROM ramphs WHERE capacity > 20000""",conn))

# this means you can use pandas .groupby on it. This is familiar from last week
pd.read_sql("""SELECT modcountry,capacity FROM ramphs""",conn).groupby('modcountry').count()
# Out:
#                  capacity
# modcountry
# Albania                 1
# Algeria                 6
# Austria                 3
# Bulgaria                2
# Croatia                 2
# Cyprus                  0
# France                 18
# Germany                 2
# Greece                  1
# Hungary                 0
# Israel                  1
# Italy                  39
# Libya                   3
# Morocco                 0
# Netherlands             0
# Northern Cyprus         0
# Portugal                1
# Romania                 1
# Serbia                  1
# Spain                   6
# Switzerland             4
# Syria                   1
# Tunisia                22
# Turkey                  1
# United Kingdom          6

# %%
# You now have all the piecces to move towards completing and going beyond
# the task I set in class. The task was:

# "For each amphitheater with a Pleiades ID,
# list that ID's ancient name(s) and chronological information
# First step... what are the steps?"

# At a minimum, write an SQL SELECT query that lists amphitheater IDs that have
# Pleiades identifiers along with the chronological information that pleiades records

# MORE INTERESTING AND HARDER: Write an SQL SELECT query that also lists the start column
# from the chronogrps table.
# So four columns at least: ramphs.id, chronogrps.start, pleiades.minDate, pleiades.maxDate

# once you do this it's easy to imagine a visualization of the difference between the founding
# of a city as indicated by pleiades and the construction of its amphitheater.
# A histogram of this would be nice. I'd calculate the difference using panda.
# (Or rather, that's how I did it.)

# Or think of some other manipulation that goes a step beyond the "at a minumum" query.


# Finally, as you ponder how to do the above, think about the conceptual range of DH as 
# found in this week's readings and as experienced while manipulating data in this
# ipython notebook. It's all DH and we love it all. How can theory and practice fit together?
# What other readings we've been assigned are relevant. This is just fodder for conversation.

import pandas as pd
import sqlite3

ramphs.to_sql('ramphs',conn, if_exists="replace")
chronogrps.to_sql('chronogrps', conn, if_exists="replace")
pleiades.to_sql('pleiades',conn,if_exists="replace")

ramphs['pleiades'] = ramphs['pleiades'].str.replace("http://pleiades.stoa.org/places/","")
ramphs.to_sql('ramphs',conn,if_exists="replace")
pd.read_sql("""SELECT ramphs.pleiades, pleiades.id FROM ramphs, pleiades LIMIT 10""", conn)
# Out:
#   pleiades      id
# 0   893989  265876
# 1   893989  265877
# 2   893989  265878
# 3   893989  265880
# 4   893989  265882
# 5   893989  265883
# 6   893989  265884
# 7   893989  265886
# 8   893989  265887
# 9   893989  265888

# %%
pd.read_sql("""SELECT ramphs.id, pleiades.title, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs
WHERE pleiades.id = ramphs.pleiades
ORDER BY pleiades.minDate""", conn)
# Out:
#                                  id  \
# 0              pergamumAmphitheater
# 1               antiochAmphitheater
# 2               palmyraAmphitheater
# 3                bostraAmphitheater
# 4               cyzicusAmphitheater
# 5                 arlesAmphitheater
# 6                  ludusMagnusArena
# 7           romeFlavianAmphitheater
# 8        romeAmphitheatrumCastrense
# 9               pompeiiAmphitheater
# 10           conimbrigaAmphitheater
# 11                cumaeAmphitheater
# 12      pozzuoliFlavianAmphitheater
# 13        pozzuoliEarlyAmphitheater
# 14             syracuseAmphitheater
# 15             carthageAmphitheater
# 16              corinthAmphitheater
# 17          leptisMagnaAmphitheater
# 18             empuriesAmphitheater
# 19             cagliariAmphitheater
# 20              catiniaAmphitheater
# 21              paestumAmphitheater
# 22             rusellaeAmphitheater
# 23               cyreneAmphitheater
# 24      scythopolisNysaAmphitheater
# 25            ocriculumAmphitheater
# 26                lixusAmphitheater
# 27               arezzoAmphitheater
# 28              larinumAmphitheater
# 29             grumentoAmphitheater
# ..                              ...
# 229            arnsburgAmphitheater
# 230             kunzingAmphitheater
# 231            bobadelaAmphitheater
# 232              sopronAmphitheater
# 233             dambachAmphitheater
# 234           gleisdorfAmphitheater
# 235            stMarcelAmphitheater
# 236                metzAmphitheater
# 237           grandHalfAmphitheater
# 238             albegnaAmphitheater
# 239           chassenonAmphitheater
# 240             seressiAmphitheater
# 241      genzanoPrivateAmphitheater
# 242           ainHedjahAmphitheater
# 243             portusOvalStructure
# 244   montbouyGallRomanAmphitheater
# 245             hisaryaAmphitheater
# 246         mesarafeltaAmphitheater
# 247        tigavaCastraAmphitheater
# 248               aostaAmphitheater
# 249               imolaAmphitheater
# 250                   zagaroloLudus
# 251          forumNovumAmphitheater
# 252  aurelumCommodianumAmphitheater
# 253            pollenzoAmphitheater
# 254             megiddoAmphitheater
# 255                yorkAmphitheater
# 256           barcelonaAmphitheater
# 257          chichesterAmphitheater
# 258        reggioEmiliaAmphitheater
#
#                                          title  minDate  maxDate
# 0                                     Pergamum    -1750     2000
# 1                         Antiochia/Theoupolis    -1750     2100
# 2                                      Palmyra    -1600     2100
# 3        Bostra/Col. Nova Traiana Alexandriana    -1344     2000
# 4                                      Cyzicus    -1200     2000
# 5             Theline/Col. Arelate/Constantina     -750     2100
# 6                                         Roma     -750     2100
# 7                                         Roma     -750     2100
# 8                                         Roma     -750     2100
# 9                                      Pompeii     -750     2100
# 10                                  Conimbriga     -750      640
# 11                      Cumae/Kyme (Campanian)     -750      640
# 12                        Dikaiarcheia/Puteoli     -750     2100
# 13                        Dikaiarcheia/Puteoli     -750     2100
# 14                        Syracusae/Syrakousai     -750     2100
# 15                                    Carthago     -750     2100
# 16                         Corinthus/Korinthos     -750     2100
# 17                       Neapolis/Lepcis Magna     -750      640
# 18                                    Emporiae     -750      640
# 19                                     Caralis     -750     2100
# 20                               Katane/Catina     -750     2100
# 21                          Poseidonia/Paestum     -750     2100
# 22                                    Rusellae     -750     2100
# 23                                      Cyrene     -750     2100
# 24                            Scythopolis/Nysa     -750      640
# 25                                   Ocriculum     -750     2100
# 26                                       Lixus     -750      640
# 27                                    Arretium     -750     2100
# 28                                     Larinum     -750     2100
# 29                                   Grumentum     -750     2100
# ..                                         ...      ...      ...
# 229                                   Arnsburg      -30      300
# 230                                   Quintana      -30      640
# 231                                  Elbocoris      -30      300
# 232                                 Scarbantia      -30     2100
# 233                                    Dambach      -30      300
# 234                                  Gleisdorf      -30      640
# 235                              *Argentomagus      -30     2100
# 236                                 Divodurum?      -30      300
# 237                                    Grannum      -30     2100
# 238                 Album Ingaunum/Albingaunum      -30     2100
# 239                             Cas(s)inomagus      -30     2100
# 240                                   *Seressi      -30      640
# 241                                   Antonini      -30      640
# 242                                      Agbia      -30      640
# 243                                     Portus      -30     2100
# 244                                   Montbouy      -30     2100
# 245                           Diocletianopolis      -30      640
# 246                                 Mesarfelta      -30      640
# 247                              Tigava Castra      -30      300
# 248                          Augusta Praetoria      -30     2100
# 249                             Forum Cornelii      -30     2100
# 250                                   Il Tondo      -30      300
# 251                                Forum Novum      -30      640
# 252  Municipium Aurelium Commodianum/Thibiuca?      -30      640
# 253                                  Pollentia      -30      640
# 254           Legio/Caporcotani/Maximianopolis      -30      640
# 255                                   Eburacum      -30      640
# 256                               Col. Barcino      -30     2100
# 257                                 Noviomagus      -30     2100
# 258                             Regium Lepidum      -30     2100
#
# [259 rows x 4 columns]

# %%
pd.read_sql("""SELECT ramphs.id, pleiades.title, chronogrps.start, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs, chronogrps 
WHERE (pleiades.id = ramphs.pleiades) AND (ramphs.chronogrp = chronogrps.chronogrp)
ORDER BY chronogrps.start""", conn)
# Out:
#                                  id  \
# 0               pompeiiAmphitheater
# 1                 cumaeAmphitheater
# 2         pozzuoliEarlyAmphitheater
# 3               paestumAmphitheater
# 4                avellaAmphitheater
# 5               ferentoAmphitheater
# 6               sutriumAmphitheatre
# 7               telesiaAmphitheatre
# 8               antiochAmphitheater
# 9             beneventoAmphitheater
# 10         calviRisortaAmphitheater
# 11      capuaRepublicanAmphitheater
# 12              liternoAmphitheater
# 13                 noleAmphitheater
# 14                teanoAmphitheater
# 15         suessaAruncaAmphitheater
# 16           altripaldaAmphitheater
# 17               compsaAmphitheater
# 18              corinthAmphitheater
# 19              carmonaAmphitheater
# 20               espejoAmphitheater
# 21               meridaAmphitheater
# 22           conimbrigaAmphitheater
# 23             syracuseAmphitheater
# 24             rusellaeAmphitheater
# 25      luceriaNoukeriaAmphitheater
# 26               cimiezAmphitheater
# 27               veronaAmphitheatre
# 28           albaFucensAmphitheater
# 29            cherchellAmphitheater
# ..                              ...
# 229             chemtouAmphitheater
# 230      genzanoPrivateAmphitheater
# 231           ainHedjahAmphitheater
# 232               uticaAmphitheater
# 233            tebourbaAmphitheater
# 234     hencherElKasbatAmphitheater
# 235       hencherZembraAmphitheater
# 236              botriaAmphitheater
# 237             portusOvalStructure
# 238         mesarafeltaAmphitheater
# 239        tigavaCastraAmphitheater
# 240            tusculumAmphitheater
# 241  aurelumCommodianumAmphitheater
# 242        hadrianVillaAmphitheater
# 243            gemellaeAmphitheater
# 244               toursAmphitheater
# 245              riminiAmphitheater
# 246   colAugustaRauricaAmphitheatre
# 247              tipasaAmphitheater
# 248          bullaRegiaAmphitheater
# 249         duraEuroposAmphitheater
# 250      romeAmphitheatrumCastrense
# 251       marcianopolisAmphitheater
# 252             bararusAmphitheater
# 253        castraAlbanaAmphitheater
# 254           grandHalfAmphitheater
# 255             egnaziaAmphitheater
# 256            thysdrusAmphitheater
# 257              sophiaAmphitheater
# 258         aphrodisiasAmphitheater
#
#                                          title  start  minDate  maxDate
# 0                                      Pompeii    -70     -750     2100
# 1                       Cumae/Kyme (Campanian)    -70     -750      640
# 2                         Dikaiarcheia/Puteoli    -70     -750     2100
# 3                           Poseidonia/Paestum    -70     -750     2100
# 4                                       Abella    -70     -330      640
# 5                               Lucus Feroniae    -70     -550      640
# 6                                      Sutrium    -70     -550      640
# 7                                      Telesia    -70     -330      640
# 8                         Antiochia/Theoupolis    -70    -1750     2100
# 9                        Beneventum/Maleventum    -70     -330     2100
# 10                                       Cales    -70     -550      640
# 11                                       Capua    -70     -750      640
# 12                                    Liternum    -70     -330      640
# 13                                        Nola    -70     -750      640
# 14                                    Tusculum    -70     -750     2100
# 15                              Suessa Aurunca    -70     -750      640
# 16                                   Abellinum    -70     -330      640
# 17                                      Compsa    -70     -550      640
# 18                         Corinthus/Korinthos    -49     -750     2100
# 19                                       Carmo    -49     -750     2100
# 20                   Ucubi/Col. Claritas Iulia    -49     -330      300
# 21                             Emerita Augusta    -27      -30     2100
# 22                                  Conimbriga    -27     -750      640
# 23                        Syracusae/Syrakousai    -27     -750     2100
# 24                                    Rusellae    -27     -750     2100
# 25                  Luceria/Noukeria (Apoulon)    -27     -550     2100
# 26                                   Cemenelum    -27     -330     2100
# 27                                      Verona    -27      -30      640
# 28                                 Alba Fucens    -27     -330     2100
# 29                                Iol Caesarea    -27     -550     2100
# ..                                         ...    ...      ...      ...
# 229                                   Simitthu    100     -330     2100
# 230                                   Antonini    100      -30      640
# 231                                      Agbia    100      -30      640
# 232                                      Utica    100     -750      640
# 233                             Thuburbi Minus    100     -330     2100
# 234                             Thuburbo Maius    100     -330      640
# 235                                 Uluzibbira    100     -330      640
# 236                                    Acholla    100     -330      640
# 237                                     Portus    100      -30     2100
# 238                                 Mesarfelta    100      -30      640
# 239                              Tigava Castra    100      -30      300
# 240                                   Tusculum    100     -750     2100
# 241  Municipium Aurelium Commodianum/Thibiuca?    100      -30      640
# 242                             Villa Hadriani    117     -330      640
# 243                                   Gemellae    117      -30      640
# 244                               Caesarodunum    117      -30     2100
# 245                                   Ariminum    117     -550      640
# 246                       Col. Augusta Raurica    150     -330     2100
# 247                                     Tipasa    150     -550      640
# 248                                Bulla Regia    150     -330      640
# 249                                       Dura    193     -330      640
# 250                                       Roma    193     -750     2100
# 251                              Marcianopolis    193      -30      640
# 252                                    Bararus    193      -30      640
# 253                              Castra Albana    193      -30      640
# 254                                    Grannum    200      -30     2100
# 255                            Egnatia/Gnathia    200     -750      640
# 256                                   Thysdrus    235     -330     2100
# 257                                    Serdica    235      -30     2100
# 258                                Aphrodisias    300     -550      640
#
# [259 rows x 5 columns]

# %% [markdown]
# # What if I don't accept the assignment?

# %%
# That's OK. You can always use your own data or data you download. But you need to turn in
# an iPython notebook that demonstrates skills of approximately the same level of difficulty
# as what is above. At a minimum: a many-to-one or one-to-many relationship that is queried
# via SQL and then used to say something minimally interesting. The usual "go for it" applies.
