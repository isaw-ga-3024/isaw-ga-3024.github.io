# %% [markdown]
# # Getting things going and highlighting "the problem"

# %%
import pandas as pd
import sqlite3

ramphs = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/roman-amphitheaters.csv")
chronogrps = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/chronogrps.csv")

# I put an uncompressed version of pleiades-places into my folder on the github repo
pleiades = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/heath-sebastian/pleiades-places.csv")

# One note: because it takes a long time to load the pleiades data,
# avoid running this cell again unless necessary
# As I look back on class, perhaps this is why Mikael reported 
# that his replace was taking a long time. Was the data reloading across the internet?

# %%
# ramphs, chronogrps, and pleiades are now pandas DataFrames

print(type(ramphs))
print(type(chronogrps))
print(type(pleiades))

# Again, these are pandas DataFrames, not sql tables!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# OK, to our problem in class.

# inspect the values in both DataFrmes
print(ramphs['pleiades'].head(2))
print(pleiades['id'].head(2))

# They're different. Bummer.
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object
# 0    265876
# 1    265877
# Name: id, dtype: int64

# %% [markdown]
# # A tiny bit of string manipulation

# %%
tmp = "Hello World"
tmp.replace("Hello", "") # note that this doesn't remove the space
# Out:
# ' World'

# %% [markdown]
# # A little bit of pandas dataframe manipulation

# %%
# first
ramphs.head(2)
# Out:
#                         id                         title  label  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos   Dura
# 1        arlesAmphitheater         Amphitheater at Arles  Arles
#
#                                  pleiades          type  capacity modcountry  \
# 0  http://pleiades.stoa.org/places/893989  amphitheater    1000.0      Syria
# 1  http://pleiades.stoa.org/places/148217  amphitheater   20000.0     France
#
#   chronogrp certainty                                      youtube  extmajor  \
# 0   Severan       NaN                                          NaN      50.0
# 1   Flavian       NaN  https://www.youtube.com/watch?v=oCz-76hb1LU     136.0
#
#    extminor  arenamajor  arenaminor   latitude  longitude  elevation
# 0      44.0        31.0        25.0  34.749855  40.728926        223
# 1     107.0        47.0        32.0  43.677778   4.631111         21

# %%
# then
ramphs['pleiades'].head(2)

# so it's easy to output either all columns, or just a selection.
# And it's likely that your notebook is trying to nicely format the output of ramphs.head(2).
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object

# %%
# it's easy to create new columns
ramphs['new'] = "test"
ramphs['new'].head(5)

# And look!!!! Very important to note that pandas will automatically assign "test" to all rows.
# That's one of its great powers.
# Out:
# 0    test
# 1    test
# 2    test
# 3    test
# 4    test
# Name: new, dtype: object

# %%
# combining pandas and string manipulation
ramphs['new'].str.replace("e","").head(5) # do note the ".str" before ".replace"

# Again, pandas calculates result for all rows
# Out:
# 0    tst
# 1    tst
# 2    tst
# 3    tst
# 4    tst
# Name: new, dtype: object

# %%
# here's a useful construct, though dangerous in that 
# it changes data (a concern some of you raised in class)


ramphs['new'] = ramphs['new'].str.replace("t","")
ramphs['new'].head(5)
# Out:
# 0    es
# 1    es
# 2    es
# 3    es
# 4    es
# Name: new, dtype: object

# %% [markdown]
# # Review of adding tables to an sql database (to keep our terminology straight)

# %%
# The conn variable is a 'database connection'
# we are making this database in memory, meaning it won't be saved
conn = sqlite3.connect(':memory:')

# as convenience, I've put the above in a separate cell. You may not need to run it again.

# %%
# the following two lines create sql tables from pandas DataFrames
ramphs.to_sql('ramphs',conn,if_exists="replace")
chronogrps.to_sql('chronogrps', conn, if_exists="replace")
pleiades.to_sql('pleiades', conn, if_exists="replace")

# copy-paste, then edit one of the the above lines to make a pleiades table

# %%
pd.read_sql("""PRAGMA table_info(chronogrps)""",conn)
# Out:
#    cid       name     type  notnull dflt_value  pk
# 0    0      index  INTEGER        0       None   0
# 1    1  chronogrp     TEXT        0       None   0
# 2    2      start  INTEGER        0       None   0
# 3    3        end  INTEGER        0       None   0

# %%
# let's test that we have sql tables
pd.read_sql("""SELECT id,pleiades FROM ramphs WHERE capacity > 40000""",conn)

# but that only confirms all is well working for the ramphs table.
# Good to test others as well.
# Out:
#                         id                                pleiades
# 0  romeFlavianAmphitheater  http://pleiades.stoa.org/places/423025

# %%
pd.read_sql("""SELECT chronogrp FROM chronogrps""",conn)
# Out:
#               chronogrp
# 0            Republican
# 1             Caesarean
# 2              Augustan
# 3        Julio-Claudian
# 4              Neronian
# 5               Flavian
# 6         First Century
# 7       Late1stEarly2nd
# 8             Hadrianic
# 9        Second Century
# 10  Late Second Century
# 11              Severan
# 12        Third Century
# 13         Post-Severan
# 14       Fourth Century
# 15             Imperial

# %%
# a reminder
pd.read_sql("""PRAGMA table_info(pleiades)""",conn)
# will display the columns in the pleiades table (assuming you called it 'pleiades')
# look at those columns, which ones have 'chronological' information
# Out:
#     cid                name     type  notnull dflt_value  pk
# 0     0               index  INTEGER        0       None   0
# 1     1             authors     TEXT        0       None   0
# 2     2                bbox     TEXT        0       None   0
# 3     3        connectsWith     TEXT        0       None   0
# 4     4             created     TEXT        0       None   0
# 5     5            creators     TEXT        0       None   0
# 6     6      currentVersion  INTEGER        0       None   0
# 7     7         description     TEXT        0       None   0
# 8     8              extent     TEXT        0       None   0
# 9     9        featureTypes     TEXT        0       None   0
# 10   10          geoContext     TEXT        0       None   0
# 11   11  hasConnectionsWith     TEXT        0       None   0
# 12   12                  id  INTEGER        0       None   0
# 13   13   locationPrecision     TEXT        0       None   0
# 14   14             maxDate     REAL        0       None   0
# 15   15             minDate     REAL        0       None   0
# 16   16            modified     TEXT        0       None   0
# 17   17                path     TEXT        0       None   0
# 18   18             reprLat     REAL        0       None   0
# 19   19         reprLatLong     TEXT        0       None   0
# 20   20            reprLong     REAL        0       None   0
# 21   21                tags     TEXT        0       None   0
# 22   22         timePeriods     TEXT        0       None   0
# 23   23     timePeriodsKeys     TEXT        0       None   0
# 24   24    timePeriodsRange     TEXT        0       None   0
# 25   25               title     TEXT        0       None   0
# 26   26                 uid     TEXT        0       None   0

# %%
pleiades.head(2)
# Out:
#                                              authors  \
# 0  Spann, P., DARMC, R. Talbert, S. Gillies, R. W...
# 1  Spann, P., R. Warner, R. Talbert, S. Gillies, ...
#
#                                          bbox connectsWith  \
# 0  -3.606772, 39.460299, -3.606772, 39.460299          NaN
# 1  -0.515639, 38.988847, -0.515639, 38.988847          NaN
#
#                 created    creators  currentVersion  \
# 0  2010-09-24T19:02:22Z  P.O. Spann              14
# 1  2010-09-24T19:02:24Z  P.O. Spann               2
#
#                                          description  \
# 0  An ancient settlement, likely of Celtic origin...
# 1  An ancient place, cited: BAtlas 27 D3 Contestania
#
#                                               extent featureTypes  \
# 0  {"type": "Point", "coordinates": [-3.606772, 3...   settlement
# 1  {"type": "Point", "coordinates": [-0.515639, 3...       region
#
#                                           geoContext  \
# 0                                          Consuegra
# 1  SE coastal area, E Bastetania up to R. Júcar (...
#
#                  ...                           path    reprLat  \
# 0                ...                 /places/265876  39.460299
# 1                ...                 /places/265877  38.988847
#
#            reprLatLong  reprLong  \
# 0  39.460299,-3.606772 -3.606772
# 1  38.988847,-0.515639 -0.515639
#
#                                                 tags timePeriods  \
# 0  dare:ancient=1, dare:major=1, dare:feature=maj...         HRL
# 1                                                NaN          HR
#
#                              timePeriodsKeys  timePeriodsRange  \
# 0  hellenistic-republican,roman,late-antique      -330.0,640.0
# 1               hellenistic-republican,roman      -330.0,300.0
#
#                  title                               uid
# 0  Consabura/Consabrum  3fb26862377912da0f866fc310bcaf0c
# 1          Contestania  ff0b70ad7c02ce378753e5d02f00210c
#
# [2 rows x 26 columns]

# %%
pd.read_sql("""SELECT title,maxDate,minDate,timePeriods FROM pleiades LIMIT 10""",conn)
# Out:
#                     title  maxDate  minDate timePeriods
# 0     Consabura/Consabrum    640.0   -330.0         HRL
# 1             Contestania    300.0   -330.0          HR
# 2      Cueva de la Paloma    300.0   -330.0          HR
# 3  Dianium/Hemeroskopeion   2100.0   -750.0      ACHRLM
# 4                   Ebura    300.0    -30.0           R
# 5                  Ebusus    640.0   -750.0       ACHRL
# 6         Ebusus (island)   2100.0   -750.0      ACHRLM
# 7                   Edeba    300.0    -30.0           R
# 8            Edeta/Leiria    300.0   -550.0         CHR
# 9                Edetania    300.0   -330.0          HR

# %% [markdown]
# # More mixing of pandas and sql

# %%
# worth noting that the result of pd.read_sql statement is a pandas DataFrame
type(pd.read_sql("""SELECT id FROM ramphs WHERE capacity > 20000""",conn))
# Out:
# pandas.core.frame.DataFrame

# %%
# this means you can use pandas .groupby on it. This is familiar from last week
pd.read_sql("""SELECT modcountry,capacity FROM ramphs""",conn).groupby('modcountry').count()
# Out:
#                  capacity
# modcountry
# Albania                 1
# Algeria                 6
# Austria                 3
# Bulgaria                2
# Croatia                 2
# Cyprus                  0
# France                 18
# Germany                 2
# Greece                  1
# Hungary                 0
# Israel                  1
# Italy                  39
# Libya                   3
# Morocco                 0
# Netherlands             0
# Northern Cyprus         0
# Portugal                1
# Romania                 1
# Serbia                  1
# Spain                   6
# Switzerland             4
# Syria                   1
# Tunisia                22
# Turkey                  1
# United Kingdom          6

# %%
# You now have all the piecces to move towards completing and going beyond
# the task I set in class. The task was:

# "For each amphitheater with a Pleiades ID,
# list that ID's ancient name(s) and chronological information
# First step... what are the steps?"

# At a minimum, write an SQL SELECT query that lists amphitheater IDs that have
# Pleiades identifiers along with the chronological information that pleiades records

# MORE INTERESTING AND HARDER: Write an SQL SELECT query that also lists the start column
# from the chronogrps table.
# So four columns at least: ramphs.id, chronogrps.start, pleiades.minDate, pleiades.maxDate

# once you do this it's easy to imagine a visualization of the difference between the founding
# of a city as indicated by pleiades and the construction of its amphitheater.
# A histogram of this would be nice. I'd calculate the difference using panda.
# (Or rather, that's how I did it.)

# Or think of some other manipulation that goes a step beyond the "at a minumum" query.


# Finally, as you ponder how to do the above, think about the conceptual range of DH as 
# found in this week's readings and as experienced while manipulating data in this
# ipython notebook. It's all DH and we love it all. How can theory and practice fit together?
# What other readings we've been assigned are relevant. This is just fodder for conversation.

pd.read_sql("""SELECT DISTINCT ramphs.id, pleiades.title, pleiades.minDate, pleiades.maxDate
FROM ramphs, chronogrps, pleiades LIMIT 10""", conn)

#need to figure out the join...
# Out:
#                         id                   title  minDate  maxDate
# 0  duraEuroposAmphitheater     Consabura/Consabrum   -330.0    640.0
# 1  duraEuroposAmphitheater             Contestania   -330.0    300.0
# 2  duraEuroposAmphitheater      Cueva de la Paloma   -330.0    300.0
# 3  duraEuroposAmphitheater  Dianium/Hemeroskopeion   -750.0   2100.0
# 4  duraEuroposAmphitheater                   Ebura    -30.0    300.0
# 5  duraEuroposAmphitheater                  Ebusus   -750.0    640.0
# 6  duraEuroposAmphitheater         Ebusus (island)   -750.0   2100.0
# 7  duraEuroposAmphitheater                   Edeba    -30.0    300.0
# 8  duraEuroposAmphitheater            Edeta/Leiria   -550.0    300.0
# 9  duraEuroposAmphitheater                Edetania   -330.0    300.0

# %%
pleiades['uri'] = "http://pleiades.stoa.org/places/"+pleiades['id'].astype(str)
pleiades['uri'].head(5)

#adding new column
# Out:
# 0    http://pleiades.stoa.org/places/265876
# 1    http://pleiades.stoa.org/places/265877
# 2    http://pleiades.stoa.org/places/265878
# 3    http://pleiades.stoa.org/places/265880
# 4    http://pleiades.stoa.org/places/265882
# Name: uri, dtype: object

# %%
pd.read_sql("""SELECT DISTINCT ramphs.id, pleiades.title, pleiades.minDate, pleiades.maxDate
FROM ramphs, chronogrps, pleiades WHERE ramphs.pleiades=pleiades.uri LIMIT 10""", conn)

#or am I???  I'm leaving my failed attempts to show my thought process, however incorrect it may be.
# Out:
# ERROR: An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 77))
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\Nathan\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1563             else:
# -> 1564                 cur.execute(*args)
#    1565             return cur
#
# OperationalError: no such column: pleiades.uri
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-28-ab70860d685f> in <module>()
#       1 pd.read_sql("""SELECT DISTINCT ramphs.id, pleiades.title, pleiades.minDate, pleiades.maxDate
# ----> 2 FROM ramphs, chronogrps, pleiades WHERE ramphs.pleiades=pleiades.uri LIMIT 10""", conn)
#
# C:\Users\Nathan\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     497             sql, index_col=index_col, params=params,
#     498             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 499             chunksize=chunksize)
#     500
#     501     try:
#
# C:\Users\Nathan\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1597
#    1598         args = _convert_params(sql, params)
# -> 1599         cursor = self.execute(*args)
#    1600         columns = [col_desc[0] for col_desc in cursor.description]
#    1601
#
# C:\Users\Nathan\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1574             ex = DatabaseError(
#    1575                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1576             raise_with_traceback(ex)
#    1577
#    1578     @staticmethod
#
# C:\Users\Nathan\Anaconda3\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#     331         if traceback == Ellipsis:
#     332             _, _, traceback = sys.exc_info()
# --> 333         raise exc.with_traceback(traceback)
#     334 else:
#     335     # this version of raise is a syntax error in Python 3
#
# C:\Users\Nathan\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1562                 cur.execute(*args, **kwargs)
#    1563             else:
# -> 1564                 cur.execute(*args)
#    1565             return cur
#    1566         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT DISTINCT ramphs.id, pleiades.title, pleiades.minDate, pleiades.maxDate
# FROM ramphs, chronogrps, pleiades WHERE ramphs.pleiades=pleiades.uri LIMIT 10': no such column: pleiades.uri

# %%
pd.read_sql("""PRAGMA table_info(pleiades)""",conn)

#no 'uri' column; curious...
# Out:
#     cid                name     type  notnull dflt_value  pk
# 0     0               index  INTEGER        0       None   0
# 1     1             authors     TEXT        0       None   0
# 2     2                bbox     TEXT        0       None   0
# 3     3        connectsWith     TEXT        0       None   0
# 4     4             created     TEXT        0       None   0
# 5     5            creators     TEXT        0       None   0
# 6     6      currentVersion  INTEGER        0       None   0
# 7     7         description     TEXT        0       None   0
# 8     8              extent     TEXT        0       None   0
# 9     9        featureTypes     TEXT        0       None   0
# 10   10          geoContext     TEXT        0       None   0
# 11   11  hasConnectionsWith     TEXT        0       None   0
# 12   12                  id  INTEGER        0       None   0
# 13   13   locationPrecision     TEXT        0       None   0
# 14   14             maxDate     REAL        0       None   0
# 15   15             minDate     REAL        0       None   0
# 16   16            modified     TEXT        0       None   0
# 17   17                path     TEXT        0       None   0
# 18   18             reprLat     REAL        0       None   0
# 19   19         reprLatLong     TEXT        0       None   0
# 20   20            reprLong     REAL        0       None   0
# 21   21                tags     TEXT        0       None   0
# 22   22         timePeriods     TEXT        0       None   0
# 23   23     timePeriodsKeys     TEXT        0       None   0
# 24   24    timePeriodsRange     TEXT        0       None   0
# 25   25               title     TEXT        0       None   0
# 26   26                 uid     TEXT        0       None   0

# %%
ramphs['pleiades'] = ramphs['pleiades'].str.replace("http://pleiades.stoa.org/places/","")
ramphs['pleiades'].head(5)
#I'm trying to provide a link between the two tables with
# Out:
# 0    893989
# 1    148217
# 2    167717
# 3    423025
# 4    423025
# Name: pleiades, dtype: object

# %%
pleiades['id'].head(5)
#well, we have the same format...
# Out:
# 0    265876
# 1    265877
# 2    265878
# 3    265880
# 4    265882
# Name: id, dtype: int64

# %%
pd.read_sql("""SELECT ramphs.id, pleiades.id, pleiades.minDate, pleiades.maxDate
FROM ramphs, chronogrps, pleiades WHERE ramphs.pleiades = pleiades.id LIMIT 10""", conn)
#no results?
# Out:
# Empty DataFrame
# Columns: [id, title, minDate, maxDate]
# Index: []

# %%
pd.read_sql("""SELECT ramphs.id, ramphs.modcountry FROM pleiades, ramphs
    WHERE pleiades.id = 893989 LIMIT 5""", conn)
#well this just seems wrong...
# Out:
#                         id modcountry
# 0  duraEuroposAmphitheater      Syria
# 1        arlesAmphitheater     France
# 2         lyonAmphitheater     France
# 3         ludusMagnusArena      Italy
# 4  romeFlavianAmphitheater      Italy

# %%
pd.read_sql("""SELECT ramphs.id, ramphs.modcountry FROM pleiades, ramphs
    WHERE pleiades.id = 423025 LIMIT 5""", conn)
#definitely wrong. different pleiades.id shouldn't be producing same results.
# Out:
#                         id modcountry
# 0  duraEuroposAmphitheater      Syria
# 1        arlesAmphitheater     France
# 2         lyonAmphitheater     France
# 3         ludusMagnusArena      Italy
# 4  romeFlavianAmphitheater      Italy

# %%
ramphs.to_sql('ramphs',conn,if_exists="replace")

# AHHH! Infuriating...missing such a simple step. Here is your head banging!

# %%
pd.read_sql("""SELECT DISTINCT ramphs.id, ramphs.title, pleiades.minDate, pleiades.maxDate
FROM ramphs, chronogrps, pleiades WHERE ramphs.pleiades = pleiades.id""", conn)
# Out:
#                                 id                                      title  \
# 0          duraEuroposAmphitheater               Amphitheater at Dura Europos
# 1                arlesAmphitheater                      Amphitheater at Arles
# 2                 lyonAmphitheater                       Amphitheater at Lyon
# 3                 ludusMagnusArena                         Ludus Magnus Arena
# 4          romeFlavianAmphitheater               Flavian Amphitheater at Rome
# 5       romeAmphitheatrumCastrense             Amphitheatrum Castrense (Rome)
# 6       eleutheropolisAmphitheater             Amphitheater at Eleutheropolis
# 199           istanbulAmphitheater                   Amphitheater at Istanbul
# 200         chichesterAmphitheater                 Amphitheater at Chichester
# 201       reggioEmiliaAmphitheater              Amphitheater at Reggio Emilia
#
#      minDate  maxDate
# 0     -330.0    640.0
# 1     -750.0   2100.0
# 2     -550.0   2100.0
# 3     -750.0   2100.0
# 4     -750.0   2100.0
# 5     -750.0   2100.0
# 6      -30.0    640.0
# 7     -750.0   2100.0
# 8      -30.0   2100.0
# 9      -30.0    300.0
# 10    -750.0    640.0
# 11    -750.0    640.0
# 12    -750.0   2100.0
# 13    -750.0   2100.0
# 14    -750.0   2100.0
# 15    -750.0   2100.0
# 16    -330.0    640.0
# 17    -750.0   2100.0
# 18     -30.0    640.0
# 19     -30.0    300.0
# 20     -30.0   2100.0
# 21     -30.0    640.0
# 22     -30.0    640.0
# 23     -30.0    640.0
# 24    -750.0    640.0
# 25    -750.0    640.0
# 26    -550.0   2100.0
# 27    -750.0   2100.0
# 28    -330.0    640.0
# 29    -330.0   2100.0
# ..       ...      ...
# 172    -30.0   2100.0
# 173   -330.0    640.0
# 174   -550.0    640.0
# 175    -30.0   2100.0
# 176   -330.0    640.0
# 177   -750.0   2100.0
# 178   -330.0    640.0
# 179   -330.0    640.0
# 180   -330.0   2100.0
# 181   -550.0    640.0
# 182   -330.0    640.0
# 183   -750.0   2100.0
# 184   -750.0   2100.0
# 185   -750.0   2100.0
# 186   -330.0    640.0
# 187   -330.0   1453.0
# 188   -550.0    640.0
# 189   -330.0    640.0
# 190    -30.0    640.0
# 191   -550.0   2100.0
# 192   -330.0    300.0
# 193    -30.0    640.0
# 194   -750.0    640.0
# 195   -330.0    640.0
# 196   -550.0    640.0
# 197    -30.0    640.0
# 198    -30.0   2100.0
# 199   -750.0    640.0
# 200    -30.0   2100.0
# 201    -30.0   2100.0
#
# [202 rows x 4 columns]

# %%
pd.read_sql("""SELECT DISTINCT ramphs.id, ramphs.title, ramphs.modcountry, pleiades.minDate, pleiades.maxDate, chronogrps.start
    FROM ramphs, chronogrps, pleiades
    WHERE ramphs.pleiades = pleiades.id
    AND ramphs.chronogrp = chronogrps.chronogrp
    ORDER BY chronogrps.start""", conn)

#success!
# Out:
#                                 id  \
# 0              pompeiiAmphitheater
# 1                cumaeAmphitheater
# 2        pozzuoliEarlyAmphitheater
# 3              paestumAmphitheater
# 4               avellaAmphitheater
# 5              ferentoAmphitheater
# 6              sutriumAmphitheatre
# 7              telesiaAmphitheatre
# 8              antiochAmphitheater
# 9            beneventoAmphitheater
# 10        calviRisortaAmphitheater
# 11               teanoAmphitheater
# 12        suessaAruncaAmphitheater
# 13          altripaldaAmphitheater
# 14              compsaAmphitheater
# 15             corinthAmphitheater
# 16             carmonaAmphitheater
# 17              espejoAmphitheater
# 18              meridaAmphitheater
# 19          conimbrigaAmphitheater
# 20            syracuseAmphitheater
# 21            rusellaeAmphitheater
# 22     luceriaNoukeriaAmphitheater
# 23              cimiezAmphitheater
# 24              veronaAmphitheatre
# 25          albaFucensAmphitheater
# 26           cherchellAmphitheater
# 27                pulaAmphitheater
# 178                  Amphitheater at Ain Hedjah      Tunisia    -30.0
# 179                       Amphitheater at Utica      Tunisia   -750.0
# 180              Amphitheater at Thuburbo Minus      Tunisia   -330.0
# 181           Amphitheater at Henchir el Kasbat      Tunisia   -330.0
# 182              Amphitheater at Henchir Zembra      Tunisia   -330.0
# 183                      Amphitheater at Botria      Tunisia   -330.0
# 184                    Oval Structure at Portus        Italy    -30.0
# 185                  Amphitheater at Mesarfelta      Algeria    -30.0
# 186               Amphitheater at Tigava Castra      Algeria    -30.0
# 187                       Tusculum Amphitheater        Italy   -750.0
# 188   Amphitheater at Hadrian's Villa at Tivoli        Italy   -330.0
# 189                    Amphitheater at Gemellae      Algeria    -30.0
# 190                      Amphitheater at Rimini        Italy   -550.0
# 191        Amphitheater at Col. Augusta Raurica  Switzerland   -330.0
# 192                      Amphitheater at Tipasa      Algeria   -550.0
# 193                 Amphitheater at Bulla Regia      Tunisia   -330.0
# 194                Amphitheater at Dura Europos        Syria   -330.0
# 195              Amphitheatrum Castrense (Rome)        Italy   -750.0
# 196      Amphitheater at Marcianopolis (Devnya)     Bulgaria    -30.0
# 197                     Amphitheater at Bararus      Tunisia    -30.0
# 198               Amphitheater at Castra Albana        Italy    -30.0
# 199                    Amphitheater at Thysdrus      Tunisia   -330.0
# 200                      Amphitheater at Sophia     Bulgaria    -30.0
# 201       Late Roman Amphitheater at Aphrodisas       Turkey   -550.0
#
#      maxDate  start
# 0     2100.0    -70
# 1      640.0    -70
# 2     2100.0    -70
# 3     2100.0    -70
# 4      640.0    -70
# 5      640.0    -70
# 6      640.0    -70
# 7      640.0    -70
# 8     2100.0    -70
# 9     2100.0    -70
# 10     640.0    -70
# 11    2100.0    -70
# 12     640.0    -70
# 13     640.0    -70
# 14     640.0    -70
# 15    2100.0    -49
# 16    2100.0    -49
# 17     300.0    -49
# 18    2100.0    -27
# 19     640.0    -27
# 20    2100.0    -27
# 21    2100.0    -27
# 22    2100.0    -27
# 23    2100.0    -27
# 24     640.0    -27
# 25    2100.0    -27
# 26    2100.0    -27
# 27    2100.0    -27
# 28    2100.0    -27
# 29     640.0    -27
# ..       ...    ...
# 172   2100.0    100
# 173   2100.0    100
# 174   2100.0    100
# 175    640.0    100
# 176   2100.0    100
# 177    640.0    100
# 178    640.0    100
# 179    640.0    100
# 180   2100.0    100
# 181    640.0    100
# 182    640.0    100
# 183    640.0    100
# 184   2100.0    100
# 185    640.0    100
# 186    300.0    100
# 187   2100.0    100
# 188    640.0    117
# 189    640.0    117
# 190    640.0    117
# 191   2100.0    150
# 192    640.0    150
# 193    640.0    150
# 194    640.0    193
# 195   2100.0    193
# 196    640.0    193
# 197    640.0    193
# 198    640.0    193
# 199   2100.0    235
# 200   2100.0    235
# 201    640.0    300
#
# [202 rows x 6 columns]

# %% [markdown]
# # What if I don't accept the assignment?

# %%
# That's OK. You can always use your own data or data you download. But you need to turn in
# an iPython notebook that demonstrates skills of approximately the same level of difficulty
# as what is above. At a minimum: a many-to-one or one-to-many relationship that is queried
# via SQL and then used to say something minimally interesting. The usual "go for it" applies.
