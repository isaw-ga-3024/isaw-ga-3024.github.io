# %% [markdown]
# # Getting things going and highlighting "the problem"

# %%
import pandas as pd
import sqlite3

ramphs = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/roman-amphitheaters.csv")
chronogrps = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/chronogrps.csv")

# I put an uncompressed version of pleiades-places into my folder on the github repo
pleiades = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/heath-sebastian/pleiades-places.csv")

# One note: because it takes a long time to load the pleiades data,
# avoid running this cell again unless necessary
# As I look back on class, perhaps this is why Mikael reported 
# that his replace was taking a long time. Was the data reloading across the internet?

# %%
# ramphs, chronogrps, and pleiades are now pandas DataFrames

print(type(ramphs))
print(type(chronogrps))
print(type(pleiades))

# Again, these are pandas DataFrames, not sql tables!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# OK, to our problem in class.

# inspect the values in both DataFrmes
print(ramphs['pleiades'].head(2))
print(pleiades['id'].head(2))

# They're different. Bummer.
# Out:
# 0    893989
# 1    148217
# Name: pleiades, dtype: object
# 0    265876
# 1    265877
# Name: id, dtype: int64

# %% [markdown]
# # A tiny bit of string manipulation

# %%
tmp = "Hello World"
tmp.replace("Hello", "") # note that this doesn't remove the space
# Out:
# ' World'

# %% [markdown]
# # A little bit of pandas dataframe manipulation

# %%
# first
ramphs.head(2)
# Out:
#                         id                         title  label pleiades  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos   Dura   893989
# 1        arlesAmphitheater         Amphitheater at Arles  Arles   148217
#
#            type  capacity modcountry chronogrp certainty  \
# 0  amphitheater    1000.0      Syria   Severan       NaN
# 1  amphitheater   20000.0     France   Flavian       NaN
#
#                                        youtube  extmajor  extminor  \
# 0                                          NaN      50.0      44.0
# 1  https://www.youtube.com/watch?v=oCz-76hb1LU     136.0     107.0
#
#    arenamajor  arenaminor   latitude  longitude  elevation
# 0        31.0        25.0  34.749855  40.728926        223
# 1        47.0        32.0  43.677778   4.631111         21

# %%
# then
ramphs['pleiades'].head(2)

# so it's easy to output either all columns, or just a selection.
# And it's likely that your notebook is trying to nicely format the output of ramphs.head(2).
# Out:
# 0    893989
# 1    148217
# Name: pleiades, dtype: object

# %%
# it's easy to create new columns
ramphs['new'] = "test"
ramphs['new'].head(5)
ramphs.head(2)
# And look!!!! Very important to note that pandas will automatically assign "test" to all rows.
# That's one of its great powers.
# Out:
#                         id                         title  label pleiades  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos   Dura   893989
# 1        arlesAmphitheater         Amphitheater at Arles  Arles   148217
#
#            type  capacity modcountry chronogrp certainty  \
# 0  amphitheater    1000.0      Syria   Severan       NaN
# 1  amphitheater   20000.0     France   Flavian       NaN
#
#                                        youtube  extmajor  extminor  \
# 0                                          NaN      50.0      44.0
# 1  https://www.youtube.com/watch?v=oCz-76hb1LU     136.0     107.0
#
#    arenamajor  arenaminor   latitude  longitude  elevation   new
# 0        31.0        25.0  34.749855  40.728926        223  test
# 1        47.0        32.0  43.677778   4.631111         21  test

# %%
# combining pandas and string manipulation
ramphs['new'].str.replace("e","").head(5) # do note the ".str" before ".replace"
# Again, pandas calculates result for all rows
# Out:
# 0    tst
# 1    tst
# 2    tst
# 3    tst
# 4    tst
# Name: new, dtype: object

# %%
# here's a useful construct, though dangerous in that 
# it changes data (a concern some of you raised in class)


ramphs['new'] = ramphs['new'].str.replace("t","")
ramphs['new'].head(5)
# Out:
# 0    es
# 1    es
# 2    es
# 3    es
# 4    es
# Name: new, dtype: object

# %% [markdown]
# # Review of adding tables to an sql database (to keep our terminology straight)

# %%
# The conn variable is a 'database connection'
# we are making this database in memory, meaning it won't be saved
conn = sqlite3.connect(':memory:')

# as convenience, I've put the above in a separate cell. You may not need to run it again.

# %%
# the following two lines create sql tables from pandas DataFrames
ramphs.to_sql('ramphs',conn,if_exists="replace")
chronogrps.to_sql('chronogrps', conn, if_exists="replace")

# copy-paste, then edit one of the the above lines to make a pleiades table

# %%
# let's test that we have sql tables
pd.read_sql("""SELECT id,pleiades FROM RAMPHS WHERE capacity > 40000""",conn)

# but that only confirms all is well working for the ramphs table.
# Good to test others as well.
# Out:
#                         id pleiades
# 0  romeFlavianAmphitheater   423025

# %%
# a reminder
pd.read_sql("""PRAGMA table_info(pleiades)""",conn)
# will display the columns in the pleiades table (assuming you called it 'pleiades')
# look at those columns, which ones have 'chronological' information
# Out:
#     cid                name     type  notnull dflt_value  pk
# 0     0               index  INTEGER        0       None   0
# 1     1             authors     TEXT        0       None   0
# 2     2                bbox     TEXT        0       None   0
# 3     3        connectsWith     TEXT        0       None   0
# 4     4             created     TEXT        0       None   0
# 5     5            creators     TEXT        0       None   0
# 6     6      currentVersion  INTEGER        0       None   0
# 7     7         description     TEXT        0       None   0
# 8     8              extent     TEXT        0       None   0
# 9     9        featureTypes     TEXT        0       None   0
# 10   10          geoContext     TEXT        0       None   0
# 11   11  hasConnectionsWith     TEXT        0       None   0
# 12   12                  id  INTEGER        0       None   0
# 13   13   locationPrecision     TEXT        0       None   0
# 14   14             maxDate     REAL        0       None   0
# 15   15             minDate     REAL        0       None   0
# 16   16            modified     TEXT        0       None   0
# 17   17                path     TEXT        0       None   0
# 18   18             reprLat     REAL        0       None   0
# 19   19         reprLatLong     TEXT        0       None   0
# 20   20            reprLong     REAL        0       None   0
# 21   21                tags     TEXT        0       None   0
# 22   22         timePeriods     TEXT        0       None   0
# 23   23     timePeriodsKeys     TEXT        0       None   0
# 24   24    timePeriodsRange     TEXT        0       None   0
# 25   25               title     TEXT        0       None   0
# 26   26                 uid     TEXT        0       None   0

# %% [markdown]
# # More mixing of pandas and sql

# %%
# worth noting that the result of pd.read_sql statement is a pandas DataFrame
type(pd.read_sql("""SELECT id FROM ramphs WHERE capacity > 20000""",conn))

# this means you can use pandas .groupby on it. This is familiar from last week
pd.read_sql("""SELECT modcountry,capacity FROM ramphs""",conn).groupby('modcountry').count()
# Out:
#                  capacity
# modcountry
# Albania                 1
# Algeria                 6
# Austria                 3
# Bulgaria                2
# Croatia                 2
# Cyprus                  0
# France                 18
# Germany                 2
# Greece                  1
# Hungary                 0
# Israel                  1
# Italy                  39
# Libya                   3
# Morocco                 0
# Netherlands             0
# Northern Cyprus         0
# Portugal                1
# Romania                 1
# Serbia                  1
# Spain                   6
# Switzerland             4
# Syria                   1
# Tunisia                22
# Turkey                  1
# United Kingdom          6

# %% [markdown]
# # Start Assignment

# %%
import pandas as pd
import sqlite3

ramphs = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/roman-amphitheaters.csv")
chronogrps = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/chronogrps.csv")
pleiades = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/heath-sebastian/pleiades-places.csv")

# %%
ramphs.to_sql('ramphs',conn,if_exists="replace")
chronogrps.to_sql('chronogrps', conn, if_exists="replace")
pleiades.to_sql('pleiades',conn,if_exists="replace")

# %%
ramphs['pleiades'] = ramphs['pleiades'].str.replace("http://pleiades.stoa.org/places/","")
ramphs.to_sql('ramphs',conn,if_exists="replace")
pd.read_sql("""SELECT ramphs.pleiades, pleiades.id FROM ramphs, pleiades LIMIT 10""", conn)
# Out:
#   pleiades      id
# 0   893989  265876
# 1   893989  265877
# 2   893989  265878
# 3   893989  265880
# 4   893989  265882
# 5   893989  265883
# 6   893989  265884
# 7   893989  265886
# 8   893989  265887
# 9   893989  265888

# %%
pd.read_sql("""SELECT ramphs.id, pleiades.title, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs
WHERE pleiades.id = ramphs.pleiades
ORDER BY pleiades.minDate""", conn)
# Out:
#                                 id                                  title  \
# 0             pergamumAmphitheater                               Pergamum
# 1              antiochAmphitheater                   Antiochia/Theoupolis
# 2               bostraAmphitheater  Bostra/Col. Nova Traiana Alexandriana
# 3              cyzicusAmphitheater                                Cyzicus
# 4                arlesAmphitheater       Theline/Col. Arelate/Constantina
# 5                 ludusMagnusArena                                   Roma
# 6          romeFlavianAmphitheater                                   Roma
# 7       romeAmphitheatrumCastrense                                   Roma
# 8              pompeiiAmphitheater                                Pompeii
# 9           conimbrigaAmphitheater                             Conimbriga
# 10               cumaeAmphitheater                 Cumae/Kyme (Campanian)
# 11     pozzuoliFlavianAmphitheater                   Dikaiarcheia/Puteoli
# 12       pozzuoliEarlyAmphitheater                   Dikaiarcheia/Puteoli
# 13            syracuseAmphitheater                   Syracusae/Syrakousai
# 14            carthageAmphitheater                               Carthago
# 15             corinthAmphitheater                    Corinthus/Korinthos
# 16         leptisMagnaAmphitheater                  Neapolis/Lepcis Magna
# 17            empuriesAmphitheater                               Emporiae
# 18            cagliariAmphitheater                                Caralis
# 19             catiniaAmphitheater                          Katane/Catina
# 20             paestumAmphitheater                     Poseidonia/Paestum
# 21            rusellaeAmphitheater                               Rusellae
# 22              cyreneAmphitheater                                 Cyrene
# 23     scythopolisNysaAmphitheater                       Scythopolis/Nysa
# 24           ocriculumAmphitheater                              Ocriculum
# 25               lixusAmphitheater                                  Lixus
# 26              arezzoAmphitheater                               Arretium
# 27             larinumAmphitheater                                Larinum
# 28            grumentoAmphitheater                              Grumentum
# 29               tiburAmphitheater                                  Tibur
# ..                             ...                                    ...
# 192            caparraAmphitheater                                 Capera
# 193          lillebonnAmphitheater                              Iuliobona
# 194            limogesAmphitheater                           Augustoritum
# 195               agenAmphitheater                                Aginnum
# 196              meauxAmphitheater                      Iatinon/Fixtuinum
# 197           chartresAmphitheater                               Autricum
# 198             senlisAmphitheater                           Augustomagus
# 199              toursAmphitheater                           Caesarodunum
# 200    caistorStEdmundAmphitheater                                  Venta
# 201           stMarcelAmphitheater                          *Argentomagus
# 202               metzAmphitheater                             Divodurum?
# 203          grandHalfAmphitheater                                Grannum
# 204            albegnaAmphitheater             Album Ingaunum/Albingaunum
# 205          chassenonAmphitheater                         Cas(s)inomagus
# 206            seressiAmphitheater                               *Seressi
# 207     genzanoPrivateAmphitheater                               Antonini
# 208          ainHedjahAmphitheater                                  Agbia
# 209            portusOvalStructure                                 Portus
# 210  montbouyGallRomanAmphitheater                               Montbouy
# 211            hisaryaAmphitheater                       Diocletianopolis
# 212        mesarafeltaAmphitheater                             Mesarfelta
# 213       tigavaCastraAmphitheater                          Tigava Castra
# 214              aostaAmphitheater                      Augusta Praetoria
# 215              imolaAmphitheater                         Forum Cornelii
# 216           pollenzoAmphitheater                              Pollentia
# 217            megiddoAmphitheater       Legio/Caporcotani/Maximianopolis
# 218               yorkAmphitheater                               Eburacum
# 219          barcelonaAmphitheater                           Col. Barcino
# 220         chichesterAmphitheater                             Noviomagus
# 221       reggioEmiliaAmphitheater                         Regium Lepidum
#
#      minDate  maxDate
# 0    -1750.0   2000.0
# 1    -1750.0   2100.0
# 2    -1344.0   2000.0
# 3    -1200.0   2000.0
# 4     -750.0   2100.0
# 5     -750.0   2100.0
# 6     -750.0   2100.0
# 7     -750.0   2100.0
# 8     -750.0   2100.0
# 9     -750.0    640.0
# 10    -750.0    640.0
# 11    -750.0   2100.0
# 12    -750.0   2100.0
# 13    -750.0   2100.0
# 14    -750.0   2100.0
# 15    -750.0   2100.0
# 16    -750.0    640.0
# 17    -750.0    640.0
# 18    -750.0   2100.0
# 19    -750.0   2100.0
# 20    -750.0   2100.0
# 21    -750.0   2100.0
# 22    -750.0   2100.0
# 23    -750.0    640.0
# 24    -750.0   2100.0
# 25    -750.0    640.0
# 26    -750.0   2100.0
# 27    -750.0   2100.0
# 28    -750.0   2100.0
# 29    -750.0    640.0
# ..       ...      ...
# 192    -30.0    640.0
# 193    -30.0   2100.0
# 194    -30.0   2100.0
# 195    -30.0   2100.0
# 196    -30.0   2100.0
# 197    -30.0   2100.0
# 198    -30.0   2100.0
# 199    -30.0   2100.0
# 200    -30.0    640.0
# 201    -30.0   2100.0
# 202    -30.0    300.0
# 203    -30.0   2100.0
# 204    -30.0   2100.0
# 205    -30.0   2100.0
# 206    -30.0    640.0
# 207    -30.0    640.0
# 208    -30.0    640.0
# 209    -30.0   2100.0
# 210    -30.0   2100.0
# 211    -30.0    640.0
# 212    -30.0    640.0
# 213    -30.0    300.0
# 214    -30.0   2100.0
# 215    -30.0   2100.0
# 216    -30.0    640.0
# 217    -30.0    640.0
# 218    -30.0    640.0
# 219    -30.0   2100.0
# 220    -30.0   2100.0
# 221    -30.0   2100.0
#
# [222 rows x 4 columns]

# %%
pd.read_sql("""SELECT ramphs.id, chronogrps.start, pleiades.title, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs, chronogrps 
WHERE (pleiades.id = ramphs.pleiades) AND (ramphs.chronogrp = chronogrps.chronogrp)
ORDER BY chronogrps.start""", conn)
# Out:
#                                 id  start                       title  \
# 0              pompeiiAmphitheater    -70                     Pompeii
# 1                cumaeAmphitheater    -70      Cumae/Kyme (Campanian)
# 2        pozzuoliEarlyAmphitheater    -70        Dikaiarcheia/Puteoli
# 3              paestumAmphitheater    -70          Poseidonia/Paestum
# 4               avellaAmphitheater    -70                      Abella
# 5              ferentoAmphitheater    -70              Lucus Feroniae
# 6              sutriumAmphitheatre    -70                     Sutrium
# 7              telesiaAmphitheatre    -70                     Telesia
# 8              antiochAmphitheater    -70        Antiochia/Theoupolis
# 9            beneventoAmphitheater    -70       Beneventum/Maleventum
# 10        calviRisortaAmphitheater    -70                       Cales
# 11     capuaRepublicanAmphitheater    -70                       Capua
# 12             liternoAmphitheater    -70                    Liternum
# 13               teanoAmphitheater    -70                    Tusculum
# 14        suessaAruncaAmphitheater    -70              Suessa Aurunca
# 15          altripaldaAmphitheater    -70                   Abellinum
# 16              compsaAmphitheater    -70                      Compsa
# 17             corinthAmphitheater    -49         Corinthus/Korinthos
# 18             carmonaAmphitheater    -49                       Carmo
# 19              espejoAmphitheater    -49   Ucubi/Col. Claritas Iulia
# 20              meridaAmphitheater    -27             Emerita Augusta
# 21          conimbrigaAmphitheater    -27                  Conimbriga
# 22            syracuseAmphitheater    -27        Syracusae/Syrakousai
# 23            rusellaeAmphitheater    -27                    Rusellae
# 24     luceriaNoukeriaAmphitheater    -27  Luceria/Noukeria (Apoulon)
# 25              cimiezAmphitheater    -27                   Cemenelum
# 26              veronaAmphitheatre    -27                      Verona
# 27          albaFucensAmphitheater    -27                 Alba Fucens
# 28           cherchellAmphitheater    -27                Iol Caesarea
# 29                pulaAmphitheater    -27                        Pola
# ..                             ...    ...                         ...
# 192             amiensAmphitheater    100      Samarobriva Ambianorum
# 193            seressiAmphitheater    100                    *Seressi
# 194            chemtouAmphitheater    100                    Simitthu
# 195     genzanoPrivateAmphitheater    100                    Antonini
# 196          ainHedjahAmphitheater    100                       Agbia
# 197              uticaAmphitheater    100                       Utica
# 198           tebourbaAmphitheater    100              Thuburbi Minus
# 199    hencherElKasbatAmphitheater    100              Thuburbo Maius
# 200      hencherZembraAmphitheater    100                  Uluzibbira
# 201             botriaAmphitheater    100                     Acholla
# 202            portusOvalStructure    100                      Portus
# 203        mesarafeltaAmphitheater    100                  Mesarfelta
# 204       tigavaCastraAmphitheater    100               Tigava Castra
# 205           tusculumAmphitheater    100                    Tusculum
# 206       hadrianVillaAmphitheater    117              Villa Hadriani
# 207           gemellaeAmphitheater    117                    Gemellae
# 208              toursAmphitheater    117                Caesarodunum
# 209             riminiAmphitheater    117                    Ariminum
# 210  colAugustaRauricaAmphitheatre    150        Col. Augusta Raurica
# 211             tipasaAmphitheater    150                      Tipasa
# 212         bullaRegiaAmphitheater    150                 Bulla Regia
# 213        duraEuroposAmphitheater    193                        Dura
# 214     romeAmphitheatrumCastrense    193                        Roma
# 215      marcianopolisAmphitheater    193               Marcianopolis
# 216            bararusAmphitheater    193                     Bararus
# 217       castraAlbanaAmphitheater    193               Castra Albana
# 218          grandHalfAmphitheater    200                     Grannum
# 219           thysdrusAmphitheater    235                    Thysdrus
# 220             sophiaAmphitheater    235                     Serdica
# 221        aphrodisiasAmphitheater    300                 Aphrodisias
#
#      minDate  maxDate
# 0     -750.0   2100.0
# 1     -750.0    640.0
# 2     -750.0   2100.0
# 3     -750.0   2100.0
# 4     -330.0    640.0
# 5     -550.0    640.0
# 6     -550.0    640.0
# 7     -330.0    640.0
# 8    -1750.0   2100.0
# 9     -330.0   2100.0
# 10    -550.0    640.0
# 11    -750.0    640.0
# 12    -330.0    640.0
# 13    -750.0   2100.0
# 14    -750.0    640.0
# 15    -330.0    640.0
# 16    -550.0    640.0
# 17    -750.0   2100.0
# 18    -750.0   2100.0
# 19    -330.0    300.0
# 20     -30.0   2100.0
# 21    -750.0    640.0
# 22    -750.0   2100.0
# 23    -750.0   2100.0
# 24    -550.0   2100.0
# 25    -330.0   2100.0
# 26     -30.0    640.0
# 27    -330.0   2100.0
# 28    -550.0   2100.0
# 29    -330.0   2100.0
# ..       ...      ...
# 192   -330.0   2100.0
# 193    -30.0    640.0
# 194   -330.0   2100.0
# 195    -30.0    640.0
# 196    -30.0    640.0
# 197   -750.0    640.0
# 198   -330.0   2100.0
# 199   -330.0    640.0
# 200   -330.0    640.0
# 201   -330.0    640.0
# 202    -30.0   2100.0
# 203    -30.0    640.0
# 204    -30.0    300.0
# 205   -750.0   2100.0
# 206   -330.0    640.0
# 207    -30.0    640.0
# 208    -30.0   2100.0
# 209   -550.0    640.0
# 210   -330.0   2100.0
# 211   -550.0    640.0
# 212   -330.0    640.0
# 213   -330.0    640.0
# 214   -750.0   2100.0
# 215    -30.0    640.0
# 216    -30.0    640.0
# 217    -30.0    640.0
# 218    -30.0   2100.0
# 219   -330.0   2100.0
# 220    -30.0   2100.0
# 221   -550.0    640.0
#
# [222 rows x 5 columns]

# %%
ramphs2 = pd.read_sql("""SELECT ramphs.id, chronogrps.start, pleiades.title, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs, chronogrps 
WHERE (pleiades.id = ramphs.pleiades) AND (ramphs.chronogrp = chronogrps.chronogrp)
ORDER BY chronogrps.start""", conn)
ramphs2.to_sql("ramphs2", conn, if_exists='replace')
ramphs2.head(225)
# Out:
#                                 id  start                       title  \
# 0              pompeiiAmphitheater    -70                     Pompeii
# 1                cumaeAmphitheater    -70      Cumae/Kyme (Campanian)
# 2        pozzuoliEarlyAmphitheater    -70        Dikaiarcheia/Puteoli
# 3              paestumAmphitheater    -70          Poseidonia/Paestum
# 4               avellaAmphitheater    -70                      Abella
# 5              ferentoAmphitheater    -70              Lucus Feroniae
# 6              sutriumAmphitheatre    -70                     Sutrium
# 7              telesiaAmphitheatre    -70                     Telesia
# 8              antiochAmphitheater    -70        Antiochia/Theoupolis
# 9            beneventoAmphitheater    -70       Beneventum/Maleventum
# 10        calviRisortaAmphitheater    -70                       Cales
# 11     capuaRepublicanAmphitheater    -70                       Capua
# 12             liternoAmphitheater    -70                    Liternum
# 13               teanoAmphitheater    -70                    Tusculum
# 14        suessaAruncaAmphitheater    -70              Suessa Aurunca
# 15          altripaldaAmphitheater    -70                   Abellinum
# 16              compsaAmphitheater    -70                      Compsa
# 17             corinthAmphitheater    -49         Corinthus/Korinthos
# 18             carmonaAmphitheater    -49                       Carmo
# 19              espejoAmphitheater    -49   Ucubi/Col. Claritas Iulia
# 20              meridaAmphitheater    -27             Emerita Augusta
# 21          conimbrigaAmphitheater    -27                  Conimbriga
# 22            syracuseAmphitheater    -27        Syracusae/Syrakousai
# 23            rusellaeAmphitheater    -27                    Rusellae
# 24     luceriaNoukeriaAmphitheater    -27  Luceria/Noukeria (Apoulon)
# 25              cimiezAmphitheater    -27                   Cemenelum
# 26              veronaAmphitheatre    -27                      Verona
# 27          albaFucensAmphitheater    -27                 Alba Fucens
# 28           cherchellAmphitheater    -27                Iol Caesarea
# 29                pulaAmphitheater    -27                        Pola
# ..                             ...    ...                         ...
# 192             amiensAmphitheater    100      Samarobriva Ambianorum
# 193            seressiAmphitheater    100                    *Seressi
# 194            chemtouAmphitheater    100                    Simitthu
# 195     genzanoPrivateAmphitheater    100                    Antonini
# 196          ainHedjahAmphitheater    100                       Agbia
# 197              uticaAmphitheater    100                       Utica
# 198           tebourbaAmphitheater    100              Thuburbi Minus
# 199    hencherElKasbatAmphitheater    100              Thuburbo Maius
# 200      hencherZembraAmphitheater    100                  Uluzibbira
# 201             botriaAmphitheater    100                     Acholla
# 202            portusOvalStructure    100                      Portus
# 203        mesarafeltaAmphitheater    100                  Mesarfelta
# 204       tigavaCastraAmphitheater    100               Tigava Castra
# 205           tusculumAmphitheater    100                    Tusculum
# 206       hadrianVillaAmphitheater    117              Villa Hadriani
# 207           gemellaeAmphitheater    117                    Gemellae
# 208              toursAmphitheater    117                Caesarodunum
# 209             riminiAmphitheater    117                    Ariminum
# 210  colAugustaRauricaAmphitheatre    150        Col. Augusta Raurica
# 211             tipasaAmphitheater    150                      Tipasa
# 212         bullaRegiaAmphitheater    150                 Bulla Regia
# 213        duraEuroposAmphitheater    193                        Dura
# 214     romeAmphitheatrumCastrense    193                        Roma
# 215      marcianopolisAmphitheater    193               Marcianopolis
# 216            bararusAmphitheater    193                     Bararus
# 217       castraAlbanaAmphitheater    193               Castra Albana
# 218          grandHalfAmphitheater    200                     Grannum
# 219           thysdrusAmphitheater    235                    Thysdrus
# 220             sophiaAmphitheater    235                     Serdica
# 221        aphrodisiasAmphitheater    300                 Aphrodisias
#
#      minDate  maxDate
# 0     -750.0   2100.0
# 1     -750.0    640.0
# 2     -750.0   2100.0
# 3     -750.0   2100.0
# 4     -330.0    640.0
# 5     -550.0    640.0
# 6     -550.0    640.0
# 7     -330.0    640.0
# 8    -1750.0   2100.0
# 9     -330.0   2100.0
# 10    -550.0    640.0
# 11    -750.0    640.0
# 12    -330.0    640.0
# 13    -750.0   2100.0
# 14    -750.0    640.0
# 15    -330.0    640.0
# 16    -550.0    640.0
# 17    -750.0   2100.0
# 18    -750.0   2100.0
# 19    -330.0    300.0
# 20     -30.0   2100.0
# 21    -750.0    640.0
# 22    -750.0   2100.0
# 23    -750.0   2100.0
# 24    -550.0   2100.0
# 25    -330.0   2100.0
# 26     -30.0    640.0
# 27    -330.0   2100.0
# 28    -550.0   2100.0
# 29    -330.0   2100.0
# ..       ...      ...
# 192   -330.0   2100.0
# 193    -30.0    640.0
# 194   -330.0   2100.0
# 195    -30.0    640.0
# 196    -30.0    640.0
# 197   -750.0    640.0
# 198   -330.0   2100.0
# 199   -330.0    640.0
# 200   -330.0    640.0
# 201   -330.0    640.0
# 202    -30.0   2100.0
# 203    -30.0    640.0
# 204    -30.0    300.0
# 205   -750.0   2100.0
# 206   -330.0    640.0
# 207    -30.0    640.0
# 208    -30.0   2100.0
# 209   -550.0    640.0
# 210   -330.0   2100.0
# 211   -550.0    640.0
# 212   -330.0    640.0
# 213   -330.0    640.0
# 214   -750.0   2100.0
# 215    -30.0    640.0
# 216    -30.0    640.0
# 217    -30.0    640.0
# 218    -30.0   2100.0
# 219   -330.0   2100.0
# 220    -30.0   2100.0
# 221   -550.0    640.0
#
# [222 rows x 5 columns]

# %%
ramphs2.to_csv('ramphs2.csv')

# %%
difference = abs(ramphs2.minDate - ramphs2.start)
ramphs2['built_after_founding'] = difference
ramphs2.columns = ['Amphitheater_id', 'date_built', 'pleiades_region', 'minRegionDate', 'maxRegionDate', 'built_after_founding']
ramphs2.head(5)
# Out:
#              Amphitheater_id  date_built         pleiades_region  \
# 0        pompeiiAmphitheater         -70                 Pompeii
# 1          cumaeAmphitheater         -70  Cumae/Kyme (Campanian)
# 2  pozzuoliEarlyAmphitheater         -70    Dikaiarcheia/Puteoli
# 3        paestumAmphitheater         -70      Poseidonia/Paestum
# 4         avellaAmphitheater         -70                  Abella
#
#    minRegionDate  maxRegionDate  built_after_founding
# 0         -750.0         2100.0                 680.0
# 1         -750.0          640.0                 680.0
# 2         -750.0         2100.0                 680.0
# 3         -750.0         2100.0                 680.0
# 4         -330.0          640.0                 260.0

# %%
ramphs2.to_csv('ramphs2_final.csv')
