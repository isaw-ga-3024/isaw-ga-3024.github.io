# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import folium

map_kenchreai = folium.Map(location=[37.885, 22.9875])

folium.Marker([37.885, 22.9875], popup='Kenchreai').add_to(map_kenchreai)

map_kenchreai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
