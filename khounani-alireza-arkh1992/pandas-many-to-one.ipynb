# %% [markdown]
# # Getting things going and highlighting "the problem"

# %%
import pandas as pd
import sqlite3

ramphs = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/roman-amphitheaters.csv")
chronogrps = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/chronogrps.csv")

# I put an uncompressed version of pleiades-places into my folder on the github repo
pleiades = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/heath-sebastian/pleiades-places.csv")

# One note: because it takes a long time to load the pleiades data,
# avoid running this cell again unless necessary
# As I look back on class, perhaps this is why Mikael reported 
# that his replace was taking a long time. Was the data reloading across the internet?

# %%
# ramphs, chronogrps, and pleiades are now pandas DataFrames

print(type(ramphs))
print(type(chronogrps))
print(type(pleiades))

# Again, these are pandas DataFrames, not sql tables!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# OK, to our problem in class.

# inspect the values in both DataFrmes
print(ramphs['pleiades'].head(2))
print(pleiades['id'].head(2))

# They're different. Bummer.
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object
# 0    265876
# 1    265877
# Name: id, dtype: int64

# %% [markdown]
# # A tiny bit of string manipulation

# %%
tmp = "Hello World"
tmp.replace("Hello", "") # note that this doesn't remove the space
# Out:
# ' World'

# %% [markdown]
# # A little bit of pandas dataframe manipulation

# %%
# first
ramphs.head(2)
# Out:
#                         id                         title  label  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos   Dura
# 1        arlesAmphitheater         Amphitheater at Arles  Arles
#
#                                  pleiades          type  capacity modcountry  \
# 0  http://pleiades.stoa.org/places/893989  amphitheater      1000      Syria
# 1  http://pleiades.stoa.org/places/148217  amphitheater     20000     France
#
#   chronogrp certainty                                      youtube  extmajor  \
# 0   Severan       NaN                                          NaN        50
# 1   Flavian       NaN  https://www.youtube.com/watch?v=oCz-76hb1LU       136
#
#    extminor  arenamajor  arenaminor   latitude  longitude  elevation
# 0        44          31          25  34.749855  40.728926        223
# 1       107          47          32  43.677778   4.631111         21

# %%
# then
ramphs['pleiades'].head(2)

# so it's easy to output either all columns, or just a selection.
# And it's likely that your notebook is trying to nicely format the output of ramphs.head(2).
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object

# %%
# it's easy to create new columns
ramphs['new'] = "test"
ramphs['new'].head(5)

# And look!!!! Very important to note that pandas will automatically assign "test" to all rows.
# That's one of its great powers.
# Out:
# 0    test
# 1    test
# 2    test
# 3    test
# 4    test
# Name: new, dtype: object

# %%
# combining pandas and string manipulation
ramphs['new'].str.replace("e","").head(5) # do note the ".str" before ".replace"

# Again, pandas calculates result for all rows
# Out:
# 0    tst
# 1    tst
# 2    tst
# 3    tst
# 4    tst
# Name: new, dtype: object

# %%
# here's a useful construct, though dangerous in that 
# it changes data (a concern some of you raised in class)


ramphs['new'] = ramphs['new'].str.replace("t","")
ramphs['new'].head(5)
# Out:
# 0    es
# 1    es
# 2    es
# 3    es
# 4    es
# Name: new, dtype: object

# %% [markdown]
# # Review of adding tables to an sql database (to keep our terminology straight)

# %%
# The conn variable is a 'database connection'
# we are making this database in memory, meaning it won't be saved
conn = sqlite3.connect(':memory:')

# as convenience, I've put the above in a separate cell. You may not need to run it again.

# %%
# the following two lines create sql tables from pandas DataFrames
ramphs.to_sql('ramphs',conn,if_exists="replace")
chronogrps.to_sql('chronogrps', conn, if_exists="replace")

# copy-paste, then edit one of the the above lines to make a pleiades table

# %%
# let's test that we have sql tables
pd.read_sql("""SELECT id,pleiades FROM RAMPHS WHERE capacity > 40000""",conn)

# but that only confirms all is well working for the ramphs table.
# Good to test others as well.
# Out:
#                         id                                pleiades
# 0  romeFlavianAmphitheater  http://pleiades.stoa.org/places/423025

# %%
# a reminder
pd.read_sql("""PRAGMA table_info(pleiades)""",conn)
# will display the columns in the pleiades table (assuming you called it 'pleiades')
# look at those columns, which ones have 'chronological' information
# Out:
#     cid                name     type  notnull dflt_value  pk
# 0     0               index  INTEGER        0       None   0
# 1     1             authors     TEXT        0       None   0
# 2     2                bbox     TEXT        0       None   0
# 3     3        connectsWith     TEXT        0       None   0
# 4     4             created     TEXT        0       None   0
# 5     5            creators     TEXT        0       None   0
# 6     6      currentVersion  INTEGER        0       None   0
# 7     7         description     TEXT        0       None   0
# 8     8              extent     TEXT        0       None   0
# 9     9        featureTypes     TEXT        0       None   0
# 10   10          geoContext     TEXT        0       None   0
# 11   11  hasConnectionsWith     TEXT        0       None   0
# 12   12                  id  INTEGER        0       None   0
# 13   13   locationPrecision     TEXT        0       None   0
# 14   14             maxDate     REAL        0       None   0
# 15   15             minDate     REAL        0       None   0
# 16   16            modified     TEXT        0       None   0
# 17   17                path     TEXT        0       None   0
# 18   18             reprLat     REAL        0       None   0
# 19   19         reprLatLong     TEXT        0       None   0
# 20   20            reprLong     REAL        0       None   0
# 21   21                tags     TEXT        0       None   0
# 22   22         timePeriods     TEXT        0       None   0
# 23   23     timePeriodsKeys     TEXT        0       None   0
# 24   24    timePeriodsRange     TEXT        0       None   0
# 25   25               title     TEXT        0       None   0
# 26   26                 uid     TEXT        0       None   0

# %% [markdown]
# # More mixing of pandas and sql

# %%
# worth noting that the result of pd.read_sql statement is a pandas DataFrame
type(pd.read_sql("""SELECT id FROM ramphs WHERE capacity > 20000""",conn))

# this means you can use pandas .groupby on it. This is familiar from last week
pd.read_sql("""SELECT modcountry,capacity FROM ramphs""",conn).groupby('modcountry').count()
# Out:
#                  capacity
# modcountry
# Albania                 1
# Algeria                 6
# Austria                 3
# Bulgaria                2
# Croatia                 2
# Cyprus                  0
# France                 18
# Germany                 2
# Greece                  1
# Hungary                 0
# Israel                  1
# Italy                  39
# Libya                   3
# Morocco                 0
# Netherlands             0
# Northern Cyprus         0
# Portugal                1
# Romania                 1
# Serbia                  1
# Spain                   6
# Switzerland             4
# Syria                   1
# Tunisia                22
# Turkey                  1
# United Kingdom          6

# %%
import pandas as pd
import sqlite3

ramphs = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/roman-amphitheaters.csv")
chronogrps = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/chronogrps.csv")
pleiades = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/heath-sebastian/pleiades-places.csv")

# %%
ramphs.to_sql('ramphs',conn,if_exists="replace")
chronogrps.to_sql('chronogrps', conn, if_exists="replace")
pleiades.to_sql('pleiades',conn,if_exists="replace")

# %%
ramphs['pleiades'] = ramphs['pleiades'].str.replace("http://pleiades.stoa.org/places/","")
ramphs.to_sql('ramphs',conn,if_exists="replace")
pd.read_sql("""SELECT ramphs.pleiades, pleiades.id FROM ramphs, pleiades LIMIT 6""", conn)
# Out:
#   pleiades      id
# 0   893989  265876
# 1   893989  265877
# 2   893989  265878
# 3   893989  265880
# 4   893989  265882
# 5   893989  265883

# %%
pd.read_sql("""SELECT ramphs.id, pleiades.title, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs
WHERE pleiades.id = ramphs.pleiades
ORDER BY pleiades.minDate""", conn)
# Out:
#                                  id  \
# 0              pergamumAmphitheater
# 1               antiochAmphitheater
# 2               palmyraAmphitheater
# 3                bostraAmphitheater
# 4               cyzicusAmphitheater
# 5                 arlesAmphitheater
# 6                  ludusMagnusArena
# 7           romeFlavianAmphitheater
# 8        romeAmphitheatrumCastrense
# 9               pompeiiAmphitheater
# 10           conimbrigaAmphitheater
# 11                cumaeAmphitheater
# 12      pozzuoliFlavianAmphitheater
# 13        pozzuoliEarlyAmphitheater
# 14             syracuseAmphitheater
# 15             carthageAmphitheater
# 16              corinthAmphitheater
# 17          leptisMagnaAmphitheater
# 18             empuriesAmphitheater
# 19             cagliariAmphitheater
# 20              catiniaAmphitheater
# 21              paestumAmphitheater
# 22             rusellaeAmphitheater
# 23               cyreneAmphitheater
# 24      scythopolisNysaAmphitheater
# 25            ocriculumAmphitheater
# 26                lixusAmphitheater
# 27               arezzoAmphitheater
# 28              larinumAmphitheater
# 29             grumentoAmphitheater
# ..                              ...
# 227               autunAmphitheater
# 228              xantenAmphitheater
# 229            arnsburgAmphitheater
# 230             kunzingAmphitheater
# 231            bobadelaAmphitheater
# 232              sopronAmphitheater
# 233           gleisdorfAmphitheater
# 234            stMarcelAmphitheater
# 235                metzAmphitheater
# 236           grandHalfAmphitheater
# 237             albegnaAmphitheater
# 238           chassenonAmphitheater
# 239             seressiAmphitheater
# 240      genzanoPrivateAmphitheater
# 241           ainHedjahAmphitheater
# 242             portusOvalStructure
# 243   montbouyGallRomanAmphitheater
# 244             hisaryaAmphitheater
# 245         mesarafeltaAmphitheater
# 246        tigavaCastraAmphitheater
# 247               aostaAmphitheater
# 248               imolaAmphitheater
# 249          forumNovumAmphitheater
# 250  aurelumCommodianumAmphitheater
# 251            pollenzoAmphitheater
# 252             megiddoAmphitheater
# 253                yorkAmphitheater
# 254           barcelonaAmphitheater
# 255          chichesterAmphitheater
# 256        reggioEmiliaAmphitheater
#
#                                          title  minDate  maxDate
# 0                                     Pergamum    -1750     2000
# 1                         Antiochia/Theoupolis    -1750     2100
# 2                                      Palmyra    -1600     2100
# 3        Bostra/Col. Nova Traiana Alexandriana    -1344     2000
# 4                                      Cyzicus    -1200     2000
# 5             Theline/Col. Arelate/Constantina     -750     2100
# 6                                         Roma     -750     2100
# 7                                         Roma     -750     2100
# 8                                         Roma     -750     2100
# 9                                      Pompeii     -750     2100
# 10                                  Conimbriga     -750      640
# 11                      Cumae/Kyme (Campanian)     -750      640
# 12                        Dikaiarcheia/Puteoli     -750     2100
# 13                        Dikaiarcheia/Puteoli     -750     2100
# 14                        Syracusae/Syrakousai     -750     2100
# 15                                    Carthago     -750     2100
# 16                         Corinthus/Korinthos     -750     2100
# 17                       Neapolis/Lepcis Magna     -750      640
# 18                                    Emporiae     -750      640
# 19                                     Caralis     -750     2100
# 20                               Katane/Catina     -750     2100
# 21                          Poseidonia/Paestum     -750     2100
# 22                                    Rusellae     -750     2100
# 23                                      Cyrene     -750     2100
# 24                            Scythopolis/Nysa     -750      640
# 25                                   Ocriculum     -750     2100
# 26                                       Lixus     -750      640
# 27                                    Arretium     -750     2100
# 28                                     Larinum     -750     2100
# 29                                   Grumentum     -750     2100
# ..                                         ...      ...      ...
# 227                               Augustodunum      -30     2100
# 228             Col. Ulpia Traiana/Tricensimae      -30     2100
# 229                                   Arnsburg      -30      300
# 230                                   Quintana      -30      640
# 231                                  Elbocoris      -30      300
# 232                                 Scarbantia      -30     2100
# 233                                  Gleisdorf      -30      640
# 234                              *Argentomagus      -30     2100
# 235                                 Divodurum?      -30      300
# 236                                    Grannum      -30     2100
# 237                 Album Ingaunum/Albingaunum      -30     2100
# 238                             Cas(s)inomagus      -30     2100
# 239                                   *Seressi      -30      640
# 240                                   Antonini      -30      640
# 241                                      Agbia      -30      640
# 242                                     Portus      -30     2100
# 243                                   Montbouy      -30     2100
# 244                           Diocletianopolis      -30      640
# 245                                 Mesarfelta      -30      640
# 246                              Tigava Castra      -30      300
# 247                          Augusta Praetoria      -30     2100
# 248                             Forum Cornelii      -30     2100
# 249                                Forum Novum      -30      640
# 250  Municipium Aurelium Commodianum/Thibiuca?      -30      640
# 251                                  Pollentia      -30      640
# 252           Legio/Caporcotani/Maximianopolis      -30      640
# 253                                   Eburacum      -30      640
# 254                               Col. Barcino      -30     2100
# 255                                 Noviomagus      -30     2100
# 256                             Regium Lepidum      -30     2100
#
# [257 rows x 4 columns]

# %%
pd.read_sql("""SELECT ramphs.id, chronogrps.start, pleiades.title, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs, chronogrps 
WHERE (pleiades.id = ramphs.pleiades) AND (ramphs.chronogrp = chronogrps.chronogrp)
ORDER BY chronogrps.start""", conn)
# Out:
#                                  id  start  \
# 0               pompeiiAmphitheater    -70
# 1                 cumaeAmphitheater    -70
# 2         pozzuoliEarlyAmphitheater    -70
# 3               paestumAmphitheater    -70
# 4                avellaAmphitheater    -70
# 5               ferentoAmphitheater    -70
# 6               sutriumAmphitheatre    -70
# 7               telesiaAmphitheatre    -70
# 8               antiochAmphitheater    -70
# 9             beneventoAmphitheater    -70
# 10         calviRisortaAmphitheater    -70
# 11      capuaRepublicanAmphitheater    -70
# 12              liternoAmphitheater    -70
# 13                 noleAmphitheater    -70
# 14                teanoAmphitheater    -70
# 15         suessaAruncaAmphitheater    -70
# 16           altripaldaAmphitheater    -70
# 17               compsaAmphitheater    -70
# 18              corinthAmphitheater    -49
# 19              carmonaAmphitheater    -49
# 20               espejoAmphitheater    -49
# 21               meridaAmphitheater    -27
# 22           conimbrigaAmphitheater    -27
# 23             syracuseAmphitheater    -27
# 24             rusellaeAmphitheater    -27
# 25      luceriaNoukeriaAmphitheater    -27
# 26               cimiezAmphitheater    -27
# 27               veronaAmphitheatre    -27
# 28           albaFucensAmphitheater    -27
# 29            cherchellAmphitheater    -27
# ..                              ...    ...
# 227             chemtouAmphitheater    100
# 228      genzanoPrivateAmphitheater    100
# 229           ainHedjahAmphitheater    100
# 230               uticaAmphitheater    100
# 231            tebourbaAmphitheater    100
# 232     hencherElKasbatAmphitheater    100
# 233       hencherZembraAmphitheater    100
# 234              botriaAmphitheater    100
# 235             portusOvalStructure    100
# 236         mesarafeltaAmphitheater    100
# 237        tigavaCastraAmphitheater    100
# 238            tusculumAmphitheater    100
# 239  aurelumCommodianumAmphitheater    100
# 240        hadrianVillaAmphitheater    117
# 241            gemellaeAmphitheater    117
# 242               toursAmphitheater    117
# 243              riminiAmphitheater    117
# 244   colAugustaRauricaAmphitheatre    150
# 245              tipasaAmphitheater    150
# 246          bullaRegiaAmphitheater    150
# 247         duraEuroposAmphitheater    193
# 248      romeAmphitheatrumCastrense    193
# 249       marcianopolisAmphitheater    193
# 250             bararusAmphitheater    193
# 251        castraAlbanaAmphitheater    193
# 252           grandHalfAmphitheater    200
# 253             egnaziaAmphitheater    200
# 254            thysdrusAmphitheater    235
# 255              sophiaAmphitheater    235
# 256         aphrodisiasAmphitheater    300
#
#                                          title  minDate  maxDate
# 0                                      Pompeii     -750     2100
# 1                       Cumae/Kyme (Campanian)     -750      640
# 2                         Dikaiarcheia/Puteoli     -750     2100
# 3                           Poseidonia/Paestum     -750     2100
# 4                                       Abella     -330      640
# 5                               Lucus Feroniae     -550      640
# 6                                      Sutrium     -550      640
# 7                                      Telesia     -330      640
# 8                         Antiochia/Theoupolis    -1750     2100
# 9                        Beneventum/Maleventum     -330     2100
# 10                                       Cales     -550      640
# 11                                       Capua     -750      640
# 12                                    Liternum     -330      640
# 13                                        Nola     -750      640
# 14                                    Tusculum     -750     2100
# 15                              Suessa Aurunca     -750      640
# 16                                   Abellinum     -330      640
# 17                                      Compsa     -550      640
# 18                         Corinthus/Korinthos     -750     2100
# 19                                       Carmo     -750     2100
# 20                   Ucubi/Col. Claritas Iulia     -330      300
# 21                             Emerita Augusta      -30     2100
# 22                                  Conimbriga     -750      640
# 23                        Syracusae/Syrakousai     -750     2100
# 24                                    Rusellae     -750     2100
# 25                  Luceria/Noukeria (Apoulon)     -550     2100
# 26                                   Cemenelum     -330     2100
# 27                                      Verona      -30      640
# 28                                 Alba Fucens     -330     2100
# 29                                Iol Caesarea     -550     2100
# ..                                         ...      ...      ...
# 227                                   Simitthu     -330     2100
# 228                                   Antonini      -30      640
# 229                                      Agbia      -30      640
# 230                                      Utica     -750      640
# 231                             Thuburbi Minus     -330     2100
# 232                             Thuburbo Maius     -330      640
# 233                                 Uluzibbira     -330      640
# 234                                    Acholla     -330      640
# 235                                     Portus      -30     2100
# 236                                 Mesarfelta      -30      640
# 237                              Tigava Castra      -30      300
# 238                                   Tusculum     -750     2100
# 239  Municipium Aurelium Commodianum/Thibiuca?      -30      640
# 240                             Villa Hadriani     -330      640
# 241                                   Gemellae      -30      640
# 242                               Caesarodunum      -30     2100
# 243                                   Ariminum     -550      640
# 244                       Col. Augusta Raurica     -330     2100
# 245                                     Tipasa     -550      640
# 246                                Bulla Regia     -330      640
# 247                                       Dura     -330      640
# 248                                       Roma     -750     2100
# 249                              Marcianopolis      -30      640
# 250                                    Bararus      -30      640
# 251                              Castra Albana      -30      640
# 252                                    Grannum      -30     2100
# 253                            Egnatia/Gnathia     -750      640
# 254                                   Thysdrus     -330     2100
# 255                                    Serdica      -30     2100
# 256                                Aphrodisias     -550      640
#
# [257 rows x 5 columns]

# %%
ramphs2 = pd.read_sql("""SELECT ramphs.id, chronogrps.start, pleiades.title, pleiades.minDate, pleiades.maxDate 
FROM pleiades, ramphs, chronogrps 
WHERE (pleiades.id = ramphs.pleiades) AND (ramphs.chronogrp = chronogrps.chronogrp)
ORDER BY chronogrps.start""", conn)
ramphs2.to_sql("ramphs2", conn, if_exists='replace')
ramphs2.head(230)
# Out:
#                                 id  start                        title  \
# 0              pompeiiAmphitheater    -70                      Pompeii
# 1                cumaeAmphitheater    -70       Cumae/Kyme (Campanian)
# 2        pozzuoliEarlyAmphitheater    -70         Dikaiarcheia/Puteoli
# 3              paestumAmphitheater    -70           Poseidonia/Paestum
# 4               avellaAmphitheater    -70                       Abella
# 5              ferentoAmphitheater    -70               Lucus Feroniae
# 6              sutriumAmphitheatre    -70                      Sutrium
# 7              telesiaAmphitheatre    -70                      Telesia
# 8              antiochAmphitheater    -70         Antiochia/Theoupolis
# 9            beneventoAmphitheater    -70        Beneventum/Maleventum
# 10        calviRisortaAmphitheater    -70                        Cales
# 11     capuaRepublicanAmphitheater    -70                        Capua
# 12             liternoAmphitheater    -70                     Liternum
# 13                noleAmphitheater    -70                         Nola
# 14               teanoAmphitheater    -70                     Tusculum
# 15        suessaAruncaAmphitheater    -70               Suessa Aurunca
# 16          altripaldaAmphitheater    -70                    Abellinum
# 17              compsaAmphitheater    -70                       Compsa
# 18             corinthAmphitheater    -49          Corinthus/Korinthos
# 19             carmonaAmphitheater    -49                        Carmo
# 20              espejoAmphitheater    -49    Ucubi/Col. Claritas Iulia
# 21              meridaAmphitheater    -27              Emerita Augusta
# 22          conimbrigaAmphitheater    -27                   Conimbriga
# 23            syracuseAmphitheater    -27         Syracusae/Syrakousai
# 24            rusellaeAmphitheater    -27                     Rusellae
# 25     luceriaNoukeriaAmphitheater    -27   Luceria/Noukeria (Apoulon)
# 26              cimiezAmphitheater    -27                    Cemenelum
# 27              veronaAmphitheatre    -27                       Verona
# 28          albaFucensAmphitheater    -27                  Alba Fucens
# 29           cherchellAmphitheater    -27                 Iol Caesarea
# ..                             ...    ...                          ...
# 200  carnuntumCivilianAmphitheater    100                    Carnuntum
# 201          tarragonaAmphitheater    100                 Col. Tarraco
# 202           cagliariAmphitheater    100                      Caralis
# 203            italicaAmphitheater    100                      Italica
# 204         viminaciumAmphitheater    100                   Viminacium
# 205             gennesAmphitheater    100                      *Geinum
# 206           bordeauxAmphitheater    100                    Burdigala
# 207              oudnaAmphitheater    100                       Uthina
# 208      sarmizegetusaAmphitheatre    100  Ulpia Traiana Sarmizegetusa
# 209             salonaAmphitheatre    100                       Salona
# 210             durresAmphitheatre    100      Dyrr(h)achium/Epidamnos
# 211          lambaesisAmphitheater    100                    Lambaesis
# 212        cirencesterAmphitheater    100                     Corinium
# 213      thysdrusSmallAmphitheater    100                     Thysdrus
# 214             gortynAmphitheater    100                    Gortyn(a)
# 215         leptiminusAmphitheater    100                  Lepti Minus
# 216           caesareaAmphitheater    100    Stratonos Pyrgos/Caesarea
# 217           pergamumAmphitheater    100                     Pergamum
# 218           sabrathaAmphitheater    100           Abrotonum/Sabratha
# 219         carmarthenAmphitheater    100                   *Moridunum
# 220            sbeitlaAmphitheater    100                     Sufetula
# 221              trierAmphitheater    100      Col. Augusta Treverorum
# 222           besanconAmphitheater    100                     Vesontio
# 223            limogesAmphitheater    100                 Augustoritum
# 224             amiensAmphitheater    100       Samarobriva Ambianorum
# 225         silchesterAmphitheater    100                      Calleva
# 226            seressiAmphitheater    100                     *Seressi
# 227            chemtouAmphitheater    100                     Simitthu
# 228     genzanoPrivateAmphitheater    100                     Antonini
# 229          ainHedjahAmphitheater    100                        Agbia
#
#      minDate  maxDate
# 0       -750     2100
# 1       -750      640
# 2       -750     2100
# 3       -750     2100
# 4       -330      640
# 5       -550      640
# 6       -550      640
# 7       -330      640
# 8      -1750     2100
# 9       -330     2100
# 10      -550      640
# 11      -750      640
# 12      -330      640
# 13      -750      640
# 14      -750     2100
# 15      -750      640
# 16      -330      640
# 17      -550      640
# 18      -750     2100
# 19      -750     2100
# 20      -330      300
# 21       -30     2100
# 22      -750      640
# 23      -750     2100
# 24      -750     2100
# 25      -550     2100
# 26      -330     2100
# 27       -30      640
# 28      -330     2100
# 29      -550     2100
# ..       ...      ...
# 200      -30      640
# 201     -550     2100
# 202     -750     2100
# 203     -330      640
# 204      -30     2100
# 205      -30      640
# 206      -30     2100
# 207      -30      640
# 208      -30      300
# 209     -330     2100
# 210     -750      640
# 211      -30     2100
# 212      -30      640
# 213     -330     2100
# 214     -750      640
# 215     -330      640
# 216     -330     2100
# 217    -1750     2000
# 218     -750      640
# 219      -30      640
# 220      -30      640
# 221      -30     2100
# 222     -330     2100
# 223      -30     2100
# 224     -330     2100
# 225      -30     2100
# 226      -30      640
# 227     -330     2100
# 228      -30      640
# 229      -30      640
#
# [230 rows x 5 columns]

# %% [markdown]
# # What if I don't accept the assignment?
