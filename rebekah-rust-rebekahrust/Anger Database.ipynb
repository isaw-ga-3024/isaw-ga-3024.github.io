# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

ramphs = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/rebekah-rust-rebekahrust/Anger%20Database.csv")

len(ramphs)
ramphs.columns=["word", "lexical_reference_form", "play", "line_number", "playwright", "genre"]
ramphs["word"].value_counts()
# Out:
# θυμὸν            30
# ὀργῆς            24
# ὀργὴν            22
# ὀργὰς            19
# πρόθυμος         16
# θυμὸς            15
# θυμοῦ            14
# προθύμως         13
# χόλον            13
# μῆνιν             8
# προθυμίας         8
# ἐπιθυμῶ           8
# θυμός             8
# προθυμίαν         8
# πρόθυμον          7
# ὀργῇ              7
# θυμούμενος        7
# μῆνις             7
# προθυμία          7
# θυμοῦσθαι         7
# θυμῶι             7
# ὀργήν             6
# θυμόν             6
# ἐπιθυμεῖ          5
# χόλου             5
# ἐπιθυμεῖν         5
# προθυμίαι         5
# θυμῷ              5
# ὀργὰν             4
# πρόθυμός          4
#                  ..
# μελαγχολᾷς        1
# μῆνίν             1
# ὀργίζῃ            1
# ὀργῶντας          1
# χολὴν             1
# ἐπεθύμουν         1
# προθυμεῖσθ        1
# ἐπιθυμήσουσιν     1
# χολαὶ             1
# θυμοπληθὴς        1
# κἀπιθυμοῖεν       1
# ἀθυμήσαντ’        1
# ἐπεθύμησας        1
# ἀκράχολος         1
# ἐπιθυμήσας        1
# ὑπερθύμως         1
# ὀργίζηι           1
# θυμώσομαι         1
# θυμουμένωι        1
# ὠμόθυμον          1
# εὐθύμου           1
# θυμωσαμέναν       1
# ὀξυθυμηθεῖσά      1
# κἀπιθυμῶ          1
# μελαγχολῶν        1
# μηνίσασα          1
# ἐνθυμουμένοις     1
# δυσθύμῳ           1
# μηνίουσιν         1
# ὄργα              1
# Name: word, dtype: int64

# %%
ramphs["play"].value_counts()
# Out:
# medea                   39
# elektra                 27
# wasps                   27
# oedipus_tyrannus        21
# peace                   20
# antigone                19
# trachiniae              19
# oedipus_at_colonus      18
# prometheus_bound        18
# frogs                   17
# bacchae                 16
# hippolytus              16
# agamemnon               16
# eumenides               15
# ajax                    15
# suppliants              14
# clouds                  12
# wealth                  11
# herakles                11
# birds                   10
# ecclesiazusae           10
# iphigenia_at_taurus     10
# orestes                 10
# lysistrata              10
# thesmophoriazusae        9
# phoenissiae              9
# heraclidae               9
# philoctetes              9
# helen                    9
# andromache               9
# iphigenia_at_aulis       8
# alcestis                 7
# ion                      7
# hecuba                   7
# choephoroe               7
# knights                  7
# seven_against_thebes     6
# rhesus                   4
# acharnians               4
# trojans                  4
# persians                 4
# cyclops                  3
# Name: play, dtype: int64

# %%
anger_terms=ramphs["lexical_reference_form"].value_counts()
plot=anger_terms.plot(kind='pie', title="Anger Terms in Greek Tragedy and Old Comedy")
plot.set_ylabel("Frequency")

# %%
anger_terms=ramphs["lexical_reference_form"].value_counts()
plot=anger_terms.plot(kind='bar', title="Anger Terms in Greek Tragedy and Old Comedy")
plot.set_ylabel("Frequency")
plot.set_xlabel("Greek Terms")

# %%
anger_frequency_play=ramphs["play"].value_counts()
plot=anger_frequency_play.plot(kind='bar', title="Frequency of Anger Terms in Greek Tragedy and Old Comedy")
plot.set_ylabel("Frequency")
plot.set_xlabel("Plays")

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-117-c7a267d39ed4> in <module>()
# ----> 1 import plotly.plotly as py
#       2 import plotly.graph_objs as go
#
# ImportError: No module named 'plotly'
