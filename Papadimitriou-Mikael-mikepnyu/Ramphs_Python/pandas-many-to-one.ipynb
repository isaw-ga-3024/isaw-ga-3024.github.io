# %% [markdown]
# # Getting things going and highlighting "the problem"

# %%
import pandas as pd
import sqlite3

ramphs = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/roman-amphitheaters.csv")
chronogrps = pd.read_csv("https://raw.githubusercontent.com/sfsheath/roman-amphitheaters/master/chronogrps.csv")

# I put an uncompressed version of pleiades-places into my folder on the github repo
pleiades = pd.read_csv("https://raw.githubusercontent.com/isaw-ga-3024/isaw-ga-3024.github.io/master/heath-sebastian/pleiades-places.csv")

# One note: because it takes a long time to load the pleiades data,
# avoid running this cell again unless necessary
# As I look back on class, perhaps this is why Mikael reported 
# that his replace was taking a long time. Was the data reloading across the internet?

# %%
# ramphs, chronogrps, and pleiades are now pandas DataFrames

print(type(ramphs))
print(type(chronogrps))
print(type(pleiades))

# Again, these are pandas DataFrames, not sql tables!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# OK, to our problem in class.

# inspect the values in both DataFrmes
print(ramphs['pleiades'].head(2))
print(pleiades['id'].head(2))

# They're different. Bummer.
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object
# 0    265876
# 1    265877
# Name: id, dtype: int64

# %% [markdown]
# # A tiny bit of string manipulation

# %%
tmp = "Hello World"
tmp.replace("Hello", "") # note that this doesn't remove the space
# Out:
# ' World'

# %% [markdown]
# # A little bit of pandas dataframe manipulation

# %%
# first
ramphs.head(2)
# Out:
#                         id                         title  label  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos   Dura
# 1        arlesAmphitheater         Amphitheater at Arles  Arles
#
#                                  pleiades          type  capacity modcountry  \
# 0  http://pleiades.stoa.org/places/893989  amphitheater    1000.0      Syria
# 1  http://pleiades.stoa.org/places/148217  amphitheater   20000.0     France
#
#   chronogrp certainty                                      youtube  extmajor  \
# 0   Severan       NaN                                          NaN      50.0
# 1   Flavian       NaN  https://www.youtube.com/watch?v=oCz-76hb1LU     136.0
#
#    extminor  arenamajor  arenaminor   latitude  longitude  elevation
# 0      44.0        31.0        25.0  34.749855  40.728926        223
# 1     107.0        47.0        32.0  43.677778   4.631111         21

# %%
# then
ramphs['pleiades'].head(2)

# so it's easy to output either all columns, or just a selection.
# And it's likely that your notebook is trying to nicely format the output of ramphs.head(2).
# Out:
# 0    http://pleiades.stoa.org/places/893989
# 1    http://pleiades.stoa.org/places/148217
# Name: pleiades, dtype: object

# %%
# it's easy to create new columns
ramphs['new'] = "test"
ramphs['new'].head(5)

# And look!!!! Very important to note that pandas will automatically assign "test" to all rows.
# That's one of its great powers.
# Out:
# 0    test
# 1    test
# 2    test
# 3    test
# 4    test
# Name: new, dtype: object

# %%
# combining pandas and string manipulation
ramphs['new'].str.replace("e","").head(5) # do note the ".str" before ".replace"

# Again, pandas calculates result for all rows
# Out:
# 0    tst
# 1    tst
# 2    tst
# 3    tst
# 4    tst
# Name: new, dtype: object

# %%
# here's a useful construct, though dangerous in that 
# it changes data (a concern some of you raised in class)


ramphs['new'] = ramphs['new'].str.replace("t","")
ramphs['new'].head(5)
# Out:
# 0    es
# 1    es
# 2    es
# 3    es
# 4    es
# Name: new, dtype: object

# %% [markdown]
# # Review of adding tables to an sql database (to keep our terminology straight)

# %%
# The conn variable is a 'database connection'
# we are making this database in memory, meaning it won't be saved
conn = sqlite3.connect(':memory:')

# as convenience, I've put the above in a separate cell. You may not need to run it again.

# %%
# the following two lines create sql tables from pandas DataFrames
ramphs.to_sql('ramphs',conn,if_exists="replace")
chronogrps.to_sql('chronogrps', conn, if_exists="replace")
pleiades.to_sql('pleiades', conn, if_exists="replace")
# copy-paste, then edit one of the the above lines to make a pleiades table

# %%
# let's test that we have sql tables
pd.read_sql("""SELECT id,pleiades FROM RAMPHS WHERE capacity > 40000""",conn)


# but that only confirms all is well working for the ramphs table.
# Good to test others as well.
# Out:
#                         id                                pleiades
# 0  romeFlavianAmphitheater  http://pleiades.stoa.org/places/423025

# %%
pd.read_sql("""SELECT title,id 
FROM pleiades 
WHERE (maxDate > 0) AND (maxDate < 200)""",conn)
# Out:
#                        title         id
# 0   Ladle Hill Iron Age Fort  127132165
# 1             Bullsdown Camp  127132166
# 2                  The Frith  127132167
# 3            Flower's Barrow  355161047
# 4        Woden Law hill fort  728181788
# 5                 Pen-y-crug   56616071
# 6             Clovelly Dykes  975884602
# 7                    Beltany  671053357
# 8                Pencoedfoel  964510418
# 9        Pen Dinas hill fort  964510419
# 10   Maiden Castle, Cheshire   82240559
# 11           Castell Henllys  773739434
# 12           Caerau Hillfort  747167617
# 13         Battlesbury Camp   245109545
# 14     Beacon Hill Hill fort  245109546
# 15    Knook Castle hill fort  579745678
# 16              The Ridgeway  548806092
# 17              Trendle Ring  267388586
# 18      Maes Knoll hill fort   42178779
# 19     Eildon Hill hill fort  511968273
# 20             Badbury Rings  511968274
# 21          Uffington Castle  549429628
# 22                 Carn Euny   59320269
# 23           Maesbury Castle  276193890
# 24              Bat's Castle  251365402
# 25            Ruborough Camp  145602471
# 26            Cadbury Castle  859366031
# 27         Scratchbury Camp   103500678
# 28             Figsbury Ring  354354474
# 29               Bindon Hill  689737512
# 30     Uffington White Horse  858265770
# 31     White Castle hillfort  416269079
# 32            Broch of Mousa    6525101
# 33           Black Ball Camp  721382239
# 34        Grabbist hill-fort  721382240
# 35            Worlebury Camp  893850615

# %%
pd.read_sql("""SELECT chronogrp,start,end 
FROM chronogrps 
WHERE (start > 0) AND (end < 200)
ORDER BY start""",conn)
# Out:
#              chronogrp  start  end
# 0        First Century      1   99
# 1             Neronian     54   68
# 2              Flavian     69   96
# 3      Late1stEarly2nd     75  125
# 4       Second Century    100  199
# 5            Hadrianic    117  138
# 6  Late Second Century    150  199

# %%
pd.read_sql("""PRAGMA table_info(ramphs)""",conn)
# Out:
#     cid        name     type  notnull dflt_value  pk
# 0     0       index  INTEGER        0       None   0
# 1     1          id     TEXT        0       None   0
# 2     2       title     TEXT        0       None   0
# 3     3       label     TEXT        0       None   0
# 4     4    pleiades     TEXT        0       None   0
# 5     5        type     TEXT        0       None   0
# 6     6    capacity     REAL        0       None   0
# 7     7  modcountry     TEXT        0       None   0
# 8     8   chronogrp     TEXT        0       None   0
# 9     9   certainty     TEXT        0       None   0
# 10   10     youtube     TEXT        0       None   0
# 11   11    extmajor     REAL        0       None   0
# 12   12    extminor     REAL        0       None   0
# 13   13  arenamajor     REAL        0       None   0
# 14   14  arenaminor     REAL        0       None   0
# 15   15    latitude     REAL        0       None   0
# 16   16   longitude     REAL        0       None   0
# 17   17   elevation  INTEGER        0       None   0
# 18   18         new     TEXT        0       None   0

# %%
# a reminder
pd.read_sql("""PRAGMA table_info(chronogrps)""",conn)
# will display the columns in the pleiades table (assuming you called it 'pleiades')
# look at those columns, which ones have 'chronological' information
# Out:
#    cid       name     type  notnull dflt_value  pk
# 0    0      index  INTEGER        0       None   0
# 1    1  chronogrp     TEXT        0       None   0
# 2    2      start  INTEGER        0       None   0
# 3    3        end  INTEGER        0       None   0

# %%
pd.read_sql("""PRAGMA table_info(pleiades)""",conn)
# Out:
#     cid                name     type  notnull dflt_value  pk
# 0     0               index  INTEGER        0       None   0
# 1     1             authors     TEXT        0       None   0
# 2     2                bbox     TEXT        0       None   0
# 3     3        connectsWith     TEXT        0       None   0
# 4     4             created     TEXT        0       None   0
# 5     5            creators     TEXT        0       None   0
# 6     6      currentVersion  INTEGER        0       None   0
# 7     7         description     TEXT        0       None   0
# 8     8              extent     TEXT        0       None   0
# 9     9        featureTypes     TEXT        0       None   0
# 10   10          geoContext     TEXT        0       None   0
# 11   11  hasConnectionsWith     TEXT        0       None   0
# 12   12                  id  INTEGER        0       None   0
# 13   13   locationPrecision     TEXT        0       None   0
# 14   14             maxDate     REAL        0       None   0
# 15   15             minDate     REAL        0       None   0
# 16   16            modified     TEXT        0       None   0
# 17   17                path     TEXT        0       None   0
# 18   18             reprLat     REAL        0       None   0
# 19   19         reprLatLong     TEXT        0       None   0
# 20   20            reprLong     REAL        0       None   0
# 21   21                tags     TEXT        0       None   0
# 22   22         timePeriods     TEXT        0       None   0
# 23   23     timePeriodsKeys     TEXT        0       None   0
# 24   24    timePeriodsRange     TEXT        0       None   0
# 25   25               title     TEXT        0       None   0
# 26   26                 uid     TEXT        0       None   0

# %% [markdown]
# # More mixing of pandas and sql

# %%
# worth noting that the result of pd.read_sql statement is a pandas DataFrame
type(pd.read_sql("""SELECT id FROM ramphs WHERE capacity > 20000""",conn))

# this means you can use pandas .groupby on it. This is familiar from last week
pd.read_sql("""SELECT modcountry,capacity FROM ramphs""",conn).groupby('modcountry').count()
# Out:
#                  capacity
# modcountry
# Albania                 1
# Algeria                 6
# Austria                 3
# Bulgaria                2
# Croatia                 2
# Cyprus                  0
# France                 18
# Germany                 2
# Greece                  1
# Hungary                 0
# Israel                  1
# Italy                  39
# Libya                   3
# Morocco                 0
# Netherlands             0
# Northern Cyprus         0
# Portugal                1
# Romania                 1
# Serbia                  1
# Spain                   6
# Switzerland             4
# Syria                   1
# Tunisia                22
# Turkey                  1
# United Kingdom          6

# %%
# "For each amphitheater with a Pleiades ID,
# list that ID's ancient name(s) and chronological information
# First step... what are the steps?"

ramphs['pleiades'] = ramphs['pleiades'].str.replace("http://pleiades.stoa.org/places/","")
ramphs["pleiades"].head(3)
# Out:
# 0    893989
# 1    148217
# 2    167717
# Name: pleiades, dtype: object

# %%
ramphs.to_sql('ramphs',conn,if_exists="replace")

# %%
pd.read_sql("""
SELECT ramphs.pleiades
FROM ramphs
LIMIT 10
""", conn)
# Out:
#   pleiades
# 0   893989
# 1   148217
# 2   167717
# 3   423025
# 4   423025
# 5   423025
# 6   687854
# 7   433032
# 8   256155
# 9    89304

# %%
# At a minimum, write an SQL SELECT query that lists amphitheater IDs that have
# Pleiades identifiers along with the chronological information that pleiades records

pd.read_sql("""
SELECT ramphs.id,pleiades.minDate,pleiades.maxDate
FROM ramphs, pleiades
WHERE ramphs.pleiades = pleiades.id
ORDER BY pleiades.minDate
""", conn)
# Out:
#                                 id  minDate  maxDate
# 0             pergamumAmphitheater  -1750.0   2000.0
# 1              antiochAmphitheater  -1750.0   2100.0
# 2              cyzicusAmphitheater  -1200.0   2000.0
# 3                arlesAmphitheater   -750.0   2100.0
# 4                 ludusMagnusArena   -750.0   2100.0
# 5          romeFlavianAmphitheater   -750.0   2100.0
# 6       romeAmphitheatrumCastrense   -750.0   2100.0
# 7              pompeiiAmphitheater   -750.0   2100.0
# 8           conimbrigaAmphitheater   -750.0    640.0
# 9                cumaeAmphitheater   -750.0    640.0
# 10     pozzuoliFlavianAmphitheater   -750.0   2100.0
# 11       pozzuoliEarlyAmphitheater   -750.0   2100.0
# 12            syracuseAmphitheater   -750.0   2100.0
# 13            carthageAmphitheater   -750.0   2100.0
# 14             corinthAmphitheater   -750.0   2100.0
# 15         leptisMagnaAmphitheater   -750.0    640.0
# 16            empuriesAmphitheater   -750.0    640.0
# 17            cagliariAmphitheater   -750.0   2100.0
# 18             catiniaAmphitheater   -750.0   2100.0
# 19             paestumAmphitheater   -750.0   2100.0
# 20            rusellaeAmphitheater   -750.0   2100.0
# 21              cyreneAmphitheater   -750.0   2100.0
# 22     scythopolisNysaAmphitheater   -750.0    640.0
# 23           ocriculumAmphitheater   -750.0   2100.0
# 24               lixusAmphitheater   -750.0    640.0
# 25              arezzoAmphitheater   -750.0   2100.0
# 26             larinumAmphitheater   -750.0   2100.0
# 27            grumentoAmphitheater   -750.0   2100.0
# 28               tiburAmphitheater   -750.0    640.0
# 29              durresAmphitheatre   -750.0    640.0
# ..                             ...      ...      ...
# 179            sbeitlaAmphitheater    -30.0    640.0
# 180              trierAmphitheater    -30.0   2100.0
# 181              ivreaAmphitheater    -30.0   2100.0
# 182            bararusAmphitheater    -30.0    640.0
# 183       castraAlbanaAmphitheater    -30.0    640.0
# 184             sophiaAmphitheater    -30.0   2100.0
# 185            caparraAmphitheater    -30.0    640.0
# 186          lillebonnAmphitheater    -30.0   2100.0
# 187            limogesAmphitheater    -30.0   2100.0
# 188               agenAmphitheater    -30.0   2100.0
# 189              meauxAmphitheater    -30.0   2100.0
# 190           chartresAmphitheater    -30.0   2100.0
# 191              toursAmphitheater    -30.0   2100.0
# 192    caistorStEdmundAmphitheater    -30.0    640.0
# 193            seressiAmphitheater    -30.0    640.0
# 194     genzanoPrivateAmphitheater    -30.0    640.0
# 195          ainHedjahAmphitheater    -30.0    640.0
# 196            portusOvalStructure    -30.0   2100.0
# 197  montbouyGallRomanAmphitheater    -30.0   2100.0
# 198            hisaryaAmphitheater    -30.0    640.0
# 199        mesarafeltaAmphitheater    -30.0    640.0
# 200       tigavaCastraAmphitheater    -30.0    300.0
# 201              aostaAmphitheater    -30.0   2100.0
# 202              imolaAmphitheater    -30.0   2100.0
# 203           pollenzoAmphitheater    -30.0    640.0
# 204            megiddoAmphitheater    -30.0    640.0
# 205               yorkAmphitheater    -30.0    640.0
# 206          barcelonaAmphitheater    -30.0   2100.0
# 207         chichesterAmphitheater    -30.0   2100.0
# 208       reggioEmiliaAmphitheater    -30.0   2100.0
#
# [209 rows x 3 columns]

# %%
# MORE INTERESTING AND HARDER: Write an SQL SELECT query that also lists the start column
# from the chronogrps table.
# So four columns at least: ramphs.id, chronogrps.start, pleiades.minDate, pleiades.maxDate

pd.read_sql("""
SELECT ramphs.id, chronogrps.start, pleiades.minDate, pleiades.maxDate
FROM ramphs, pleiades, chronogrps
WHERE (ramphs.pleiades = pleiades.id) AND (ramphs.chronogrp = chronogrps.chronogrp)
ORDER BY chronogrps.start
""", conn)
# Out:
#                                 id  start  minDate  maxDate
# 0              pompeiiAmphitheater    -70   -750.0   2100.0
# 1                cumaeAmphitheater    -70   -750.0    640.0
# 2        pozzuoliEarlyAmphitheater    -70   -750.0   2100.0
# 3              paestumAmphitheater    -70   -750.0   2100.0
# 4               avellaAmphitheater    -70   -330.0    640.0
# 5              ferentoAmphitheater    -70   -550.0    640.0
# 6              sutriumAmphitheatre    -70   -550.0    640.0
# 7              telesiaAmphitheatre    -70   -330.0    640.0
# 8              antiochAmphitheater    -70  -1750.0   2100.0
# 9            beneventoAmphitheater    -70   -330.0   2100.0
# 10        calviRisortaAmphitheater    -70   -550.0    640.0
# 11     capuaRepublicanAmphitheater    -70   -750.0    640.0
# 12             liternoAmphitheater    -70   -330.0    640.0
# 13               teanoAmphitheater    -70   -750.0   2100.0
# 14        suessaAruncaAmphitheater    -70   -750.0    640.0
# 15          altripaldaAmphitheater    -70   -330.0    640.0
# 16              compsaAmphitheater    -70   -550.0    640.0
# 17             corinthAmphitheater    -49   -750.0   2100.0
# 18             carmonaAmphitheater    -49   -750.0   2100.0
# 19              espejoAmphitheater    -49   -330.0    300.0
# 20              meridaAmphitheater    -27    -30.0   2100.0
# 21          conimbrigaAmphitheater    -27   -750.0    640.0
# 22            syracuseAmphitheater    -27   -750.0   2100.0
# 23            rusellaeAmphitheater    -27   -750.0   2100.0
# 24     luceriaNoukeriaAmphitheater    -27   -550.0   2100.0
# 25              cimiezAmphitheater    -27   -330.0   2100.0
# 26              veronaAmphitheatre    -27    -30.0    640.0
# 27          albaFucensAmphitheater    -27   -330.0   2100.0
# 28           cherchellAmphitheater    -27   -550.0   2100.0
# 29                pulaAmphitheater    -27   -330.0   2100.0
# ..                             ...    ...      ...      ...
# 179            limogesAmphitheater    100    -30.0   2100.0
# 180             amiensAmphitheater    100   -330.0   2100.0
# 181            seressiAmphitheater    100    -30.0    640.0
# 182            chemtouAmphitheater    100   -330.0   2100.0
# 183     genzanoPrivateAmphitheater    100    -30.0    640.0
# 184          ainHedjahAmphitheater    100    -30.0    640.0
# 185              uticaAmphitheater    100   -750.0    640.0
# 186           tebourbaAmphitheater    100   -330.0   2100.0
# 187    hencherElKasbatAmphitheater    100   -330.0    640.0
# 188      hencherZembraAmphitheater    100   -330.0    640.0
# 189             botriaAmphitheater    100   -330.0    640.0
# 190            portusOvalStructure    100    -30.0   2100.0
# 191        mesarafeltaAmphitheater    100    -30.0    640.0
# 192       tigavaCastraAmphitheater    100    -30.0    300.0
# 193           tusculumAmphitheater    100   -750.0   2100.0
# 194       hadrianVillaAmphitheater    117   -330.0    640.0
# 195           gemellaeAmphitheater    117    -30.0    640.0
# 196              toursAmphitheater    117    -30.0   2100.0
# 197             riminiAmphitheater    117   -550.0    640.0
# 198  colAugustaRauricaAmphitheatre    150   -330.0   2100.0
# 199             tipasaAmphitheater    150   -550.0    640.0
# 200         bullaRegiaAmphitheater    150   -330.0    640.0
# 201        duraEuroposAmphitheater    193   -330.0    640.0
# 202     romeAmphitheatrumCastrense    193   -750.0   2100.0
# 203      marcianopolisAmphitheater    193    -30.0    640.0
# 204            bararusAmphitheater    193    -30.0    640.0
# 205       castraAlbanaAmphitheater    193    -30.0    640.0
# 206           thysdrusAmphitheater    235   -330.0   2100.0
# 207             sophiaAmphitheater    235    -30.0   2100.0
# 208        aphrodisiasAmphitheater    300   -550.0    640.0
#
# [209 rows x 4 columns]

# %%
#Foundation of Late Republican Amphitheaters vs Foundation of their Cities

pd.read_sql("""
SELECT ramphs.title, chronogrps.start, chronogrps.end, pleiades.title, pleiades.minDate, pleiades.maxDate
FROM ramphs, pleiades, chronogrps
WHERE (ramphs.pleiades = pleiades.id) AND (ramphs.chronogrp = chronogrps.chronogrp) AND (chronogrps.start >= -70 AND chronogrps.start <= -31)
ORDER BY chronogrps.start
""", conn)
# Out:
#                                title  start  end                      title  \
# 0             Amphitheater at Abella    -70  -31                     Abella
# 1         Amphitheater at Altripalda    -70  -31                  Abellinum
# 2            Amphitheater at Antioch    -70  -31       Antiochia/Theoupolis
# 3          Amphitheater at Benevento    -70  -31      Beneventum/Maleventum
# 4      Amphitheater at Calvi Risorta    -70  -31                      Cales
# 5             Amphitheater at Compsa    -70  -31                     Compsa
# 6              Amphitheater at Cumae    -70  -31     Cumae/Kyme (Campanian)
# 7            Amphitheater at Ferento    -70  -31             Lucus Feroniae
# 8            Amphitheater at Literno    -70  -31                   Liternum
# 9            Amphitheater at Paestum    -70  -31         Poseidonia/Paestum
# 10           Amphitheater at Pompeii    -70  -31                    Pompeii
# 11     Amphitheater at Suessa Arunca    -70  -31             Suessa Aurunca
# 12           Amphitheater at Sutrium    -70  -31                    Sutrium
# 13             Amphitheater at Teano    -70  -31                   Tusculum
# 14           Amphitheater at Telesia    -70  -31                    Telesia
# 15    Early Amphitheater at Pozzuoli    -70  -31       Dikaiarcheia/Puteoli
# 16  Republican Amphitheater at Capua    -70  -31                      Capua
# 17           Amphitheater at Carmona    -49  -44                      Carmo
# 18           Amphitheater at Corinth    -49  -44        Corinthus/Korinthos
# 19            Amphitheater at Espejo    -49  -44  Ucubi/Col. Claritas Iulia
#
#     minDate  maxDate
# 0    -330.0    640.0
# 1    -330.0    640.0
# 2   -1750.0   2100.0
# 3    -330.0   2100.0
# 4    -550.0    640.0
# 5    -550.0    640.0
# 6    -750.0    640.0
# 7    -550.0    640.0
# 8    -330.0    640.0
# 9    -750.0   2100.0
# 10   -750.0   2100.0
# 11   -750.0    640.0
# 12   -550.0    640.0
# 13   -750.0   2100.0
# 14   -330.0    640.0
# 15   -750.0   2100.0
# 16   -750.0    640.0
# 17   -750.0   2100.0
# 18   -750.0   2100.0
# 19   -330.0    300.0

# %%
#Difference between the date of the foundation of the city and its amphitheater during this period

df = pd.read_sql("""
SELECT ramphs.title, chronogrps.start, chronogrps.end, pleiades.title, pleiades.minDate, pleiades.maxDate
FROM ramphs, pleiades, chronogrps
WHERE (ramphs.pleiades = pleiades.id) AND (ramphs.chronogrp = chronogrps.chronogrp) AND (chronogrps.start >= -70 AND chronogrps.start <= -31)
ORDER BY chronogrps.start
""", conn)

df['Difference'] = df.start - df.minDate
print(df)
# Out:
#                                title  start  end                      title  \
# 0             Amphitheater at Abella    -70  -31                     Abella
# 1         Amphitheater at Altripalda    -70  -31                  Abellinum
# 2            Amphitheater at Antioch    -70  -31       Antiochia/Theoupolis
# 3          Amphitheater at Benevento    -70  -31      Beneventum/Maleventum
# 4      Amphitheater at Calvi Risorta    -70  -31                      Cales
# 5             Amphitheater at Compsa    -70  -31                     Compsa
# 6              Amphitheater at Cumae    -70  -31     Cumae/Kyme (Campanian)
# 7            Amphitheater at Ferento    -70  -31             Lucus Feroniae
# 8            Amphitheater at Literno    -70  -31                   Liternum
# 9            Amphitheater at Paestum    -70  -31         Poseidonia/Paestum
# 10           Amphitheater at Pompeii    -70  -31                    Pompeii
# 11     Amphitheater at Suessa Arunca    -70  -31             Suessa Aurunca
# 12           Amphitheater at Sutrium    -70  -31                    Sutrium
# 13             Amphitheater at Teano    -70  -31                   Tusculum
# 14           Amphitheater at Telesia    -70  -31                    Telesia
# 15    Early Amphitheater at Pozzuoli    -70  -31       Dikaiarcheia/Puteoli
# 16  Republican Amphitheater at Capua    -70  -31                      Capua
# 17           Amphitheater at Carmona    -49  -44                      Carmo
# 18           Amphitheater at Corinth    -49  -44        Corinthus/Korinthos
# 19            Amphitheater at Espejo    -49  -44  Ucubi/Col. Claritas Iulia
#
#     minDate  maxDate  Difference
# 0    -330.0    640.0       260.0
# 1    -330.0    640.0       260.0
# 2   -1750.0   2100.0      1680.0
# 3    -330.0   2100.0       260.0
# 4    -550.0    640.0       480.0
# 5    -550.0    640.0       480.0
# 6    -750.0    640.0       680.0
# 7    -550.0    640.0       480.0
# 8    -330.0    640.0       260.0
# 9    -750.0   2100.0       680.0
# 10   -750.0   2100.0       680.0
# 11   -750.0    640.0       680.0
# 12   -550.0    640.0       480.0
# 13   -750.0   2100.0       680.0
# 14   -330.0    640.0       260.0
# 15   -750.0   2100.0       680.0
# 16   -750.0    640.0       680.0
# 17   -750.0   2100.0       701.0
# 18   -750.0   2100.0       701.0
# 19   -330.0    300.0       281.0

# %%
#Average of the difference between the date of the foundation of the city and its amphitheater

df['Difference'].mean()
# Out:
# 567.15
